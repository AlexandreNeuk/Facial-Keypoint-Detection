# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
import random

import sys
import matplotlib
import sklearn
import numpy
import keras
import tensorflow as tf 
from keras.layers import Dense, Flatten, BatchNormalization, Dropout, Convolution2D, MaxPool2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import Callback
# Out:
# Using TensorFlow backend.

# %%
print('Versão Python ', sys.version)
print('Versão Numpy ', numpy.version.version)
print('Versão Pandas ', pd.__version__)
print('Versão Matplotlib ', matplotlib.__version__)
print('Versão Sklearn ', sklearn.__version__)
print('Versão Keras', keras.__version__)
print('Versão TensorFlow', tf.__version__)
# Out:
# Versão Python  3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:18:16) [MSC v.1916 64 bit (AMD64)]
# Versão Numpy  1.17.4
# Versão Pandas  0.25.3
# Versão Matplotlib  3.1.2
# Versão Sklearn  0.22.1
# Versão Keras 2.3.1
# Versão TensorFlow 2.0.0

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
training = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %%
training = training.dropna()

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)

# %%
y = training.drop(['Image'], axis=1)

# %%
y_ndarray = y.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_ndarray, test_size=0.3, random_state=42)

# %%
model = Sequential()

# %%
def add_model(model, filters, maxpooling, *inputshape):   
    if inputshape:
        model.add(Convolution2D(filters, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
    else:
      if maxpooling:
        model.add(Convolution2D(filters, (3,3), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
        model.add(MaxPool2D(pool_size=(2, 2)))
      else:
        model.add(Convolution2D(filters, (3,3), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())

# %%
add_model(model, 32, False, True)

# %%
add_model(model, 32, True)
add_model(model, 64, False)
add_model(model, 64, True)
#add_model(model, 128, False)
add_model(model, 128, True)
#add_model(model, 256, False)
add_model(model, 256, True)
#add_model(model, 512, False)
add_model(model, 512, True)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))

# %%
model.compile(optimizer='Adam', loss='root_mean_squared_error', metrics=['mae', 'acc'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'layer10_epoc100_kernel5p5_drop0p1.hdf5', monitor='val_mae', verbose=1, save_best_only=False)

# %%
history = model.fit(X_train, y_train, epochs=2, validation_split=0.02, callbacks=[checkpointer])
# Out:
# Train on 1468 samples, validate on 30 samples
# Epoch 1/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 157.5650 - mae: 7.7384 - acc: 0.3992 - val_loss: 23.0393 - val_mae: 3.6541 - val_acc: 0.7667
#
# Epoch 00001: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 2/100
# 1468/1468 [==============================] - 204s 139ms/step - loss: 27.6034 - mae: 4.1313 - acc: 0.4973 - val_loss: 29.6745 - val_mae: 4.4796 - val_acc: 0.7333
#
# Epoch 00002: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch
saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 79/100
# 1468/1468 [==============================] - 208s 142ms/step - loss: 4.9899 - mae: 1.7151 - acc: 0.8317 - val_loss: 2.1390 - val_mae: 1.0411 - val_acc: 0.9000
#
# Epoch 00079: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 80/100
# 1468/1468 [==============================] - 233s 158ms/step - loss: 4.1352 - mae: 1.5604 - acc: 0.8311 - val_loss: 2.3397 - val_mae: 1.1539 - val_acc: 0.8667
#
# Epoch 00080: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 81/100
# 1468/1468 [==============================] - 207s 141ms/step - loss: 4.3077 - mae: 1.5946 - acc: 0.8236 - val_loss: 4.7528 - val_mae: 1.8333 - val_acc: 0.8333
#
# Epoch 00081: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 82/100
# 1468/1468 [==============================] - 208s 142ms/step - loss: 4.1114 - mae: 1.5568 - acc: 0.8297 - val_loss: 9.3998 - val_mae: 2.6314 - val_acc: 0.8667
#
# Epoch 00082: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 83/100
# 1468/1468 [==============================] - 210s 143ms/step - loss: 3.6154 - mae: 1.4595 - acc: 0.8229 - val_loss: 5.6059 - val_mae: 2.0111 - val_acc: 0.8667
#
# Epoch 00083: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 84/100
# 1468/1468 [==============================] - 208s 142ms/step - loss: 3.8472 - mae: 1.5029 - acc: 0.8304 - val_loss: 2.1328 - val_mae: 1.0408 - val_acc: 0.8333
#
# Epoch 00084: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 85/100
# 1468/1468 [==============================] - 208s 141ms/step - loss: 5.0385 - mae: 1.7238 - acc: 0.8283 - val_loss: 4.2527 - val_mae: 1.7206 - val_acc: 0.8000
#
# Epoch 00085: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 86/100
# 1468/1468 [==============================] - 214s 146ms/step - loss: 4.4819 - mae: 1.6169 - acc: 0.8079 - val_loss: 2.6145 - val_mae: 1.2069 - val_acc: 0.8333
#
# Epoch 00086: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 87/100
# 1468/1468 [==============================] - 209s 143ms/step - loss: 4.0725 - mae: 1.5493 - acc: 0.8222 - val_loss: 2.6037 - val_mae: 1.2017 - val_acc: 0.8000
#
# Epoch 00087: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 88/100
# 1468/1468 [==============================] - 223s 152ms/step - loss: 4.3326 - mae: 1.5956 - acc: 0.8317 - val_loss: 3.8658 - val_mae: 1.5410 - val_acc: 0.8333
#
# Epoch 00088: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 89/100
# 1468/1468 [==============================] - 214s 146ms/step - loss: 4.3333 - mae: 1.5976 - acc: 0.8379 - val_loss: 1.9987 - val_mae: 1.0236 - val_acc: 0.8667
#
# Epoch 00089: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 90/100
# 1468/1468 [==============================] - 209s 142ms/step - loss: 4.1697 - mae: 1.5769 - acc: 0.8256 - val_loss: 1.9443 - val_mae: 1.0078 - val_acc: 0.8000
#
# Epoch 00090: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 91/100
# 1468/1468 [==============================] - 208s 142ms/step - loss: 3.8401 - mae: 1.5120 - acc: 0.8535 - val_loss: 9.0075 - val_mae: 2.6158 - val_acc: 0.8333
#
# Epoch 00091: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 92/100
# 1468/1468 [==============================] - 214s 146ms/step - loss: 3.7013 - mae: 1.4778 - acc: 0.8399 - val_loss: 1.8569 - val_mae: 0.9868 - val_acc: 0.8333
#
# Epoch 00092: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 93/100
# 1468/1468 [==============================] - 208s 142ms/step - loss: 3.5038 - mae: 1.4295 - acc: 0.8365 - val_loss: 5.2892 - val_mae: 1.9217 - val_acc: 0.7333
#
# Epoch 00093: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 94/100
# 1468/1468 [==============================] - 209s 142ms/step - loss: 4.0560 - mae: 1.5417 - acc: 0.8277 - val_loss: 10.4584 - val_mae: 2.8225 - val_acc: 0.8667
#
# Epoch 00094: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 95/100
# 1468/1468 [==============================] - 215s 146ms/step - loss: 4.4975 - mae: 1.6306 - acc: 0.8297 - val_loss: 4.1494 - val_mae: 1.6822 - val_acc: 0.8333
#
# Epoch 00095: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 96/100
# 1468/1468 [==============================] - 210s 143ms/step - loss: 3.4344 - mae: 1.4207 - acc: 0.8515 - val_loss: 1.7717 - val_mae: 0.9578 - val_acc: 0.8667
#
# Epoch 00096: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 97/100
# 1468/1468 [==============================] - 232s 158ms/step - loss: 3.5908 - mae: 1.4593 - acc: 0.8460 - val_loss: 6.2343 - val_mae: 2.1616 - val_acc: 0.9000
#
# Epoch 00097: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 98/100
# 1468/1468 [==============================] - 209s 143ms/step - loss: 3.5711 - mae: 1.4417 - acc: 0.8413 - val_loss: 1.9214 - val_mae: 0.9987 - val_acc: 0.8667
#
# Epoch 00098: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 99/100
# 1468/1468 [==============================] - 209s 142ms/step - loss: 3.9697 - mae: 1.5299 - acc: 0.8406 - val_loss: 2.3468 - val_mae: 1.0894 - val_acc: 0.8333
#
# Epoch 00099: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 100/100
# 1468/1468 [==============================] - 214s 146ms/step - loss: 3.2996 - mae: 1.3958 - acc: 0.8372 - val_loss: 5.5023 - val_mae: 2.0072 - val_acc: 0.8000
#
# Epoch 00100: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 5.622330626966055
# Test accuracy: 1.980099081993103

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
train_predicts = model.predict(X_train)

plt.imshow(X_train[0].reshape((96,96)), cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[0][i-1], train_predicts[0][i], 'ro')
    plt.plot(y_train[0][i-1], y_train[0][i], 'x', color='green')

plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'], linewidth=2, label="train")
plt.plot(history.history['val_loss'], linewidth=2, label="val ")
plt.legend()
plt.title('Loss vs Epoch')
plt.grid()
plt.xlabel("Epoch")
plt.ylabel("Log Loss")
fig= plt.figure(figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['mae'], linewidth=2)
plt.plot(history.history['val_mae'], linewidth=2)
plt.title('Mean Absolute Error vs Epoch')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['acc'], linewidth=2)
plt.plot(history.history['val_acc'], linewidth=2)
plt.title('Accuracy vs Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
predict = model.predict(test_X)

# %%
header = list(y.columns)

# %%
df_predict = pd.DataFrame(predict, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = df_predict.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
SampleSubmission.to_csv('submission_100_epochs_kernel3x3_mean_squared_error.csv', index=False)
