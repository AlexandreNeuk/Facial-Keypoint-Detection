# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
import random

import sys
import matplotlib
import sklearn
import numpy
import keras
import tensorflow as tf 
from keras.layers import Dense, Flatten, BatchNormalization, Dropout, Convolution2D, MaxPool2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import Callback
# Out:
# Using TensorFlow backend.

# %%
print('Versão Python ', sys.version)
print('Versão Numpy ', numpy.version.version)
print('Versão Pandas ', pd.__version__)
print('Versão Matplotlib ', matplotlib.__version__)
print('Versão Sklearn ', sklearn.__version__)
print('Versão Keras', keras.__version__)
print('Versão TensorFlow', tf.__version__)
# Out:
# Versão Python  3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:18:16) [MSC v.1916 64 bit (AMD64)]
# Versão Numpy  1.17.4
# Versão Pandas  0.25.3
# Versão Matplotlib  3.1.2
# Versão Sklearn  0.22.1
# Versão Keras 2.3.1
# Versão TensorFlow 2.0.0

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
training = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %%
training = training.dropna()

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)

# %%
y = training.drop(['Image'], axis=1)

# %%
y_ndarray = y.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_ndarray, test_size=0.3, random_state=42)

# %%
model = Sequential()

# %%
def add_model(model, filters, maxpooling, *inputshape):   
    if inputshape:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False, input_shape=(96,96,1)))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
    else:
      if maxpooling:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(MaxPool2D(pool_size=(2, 2)))
      else:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(Dropout(0.2))
        model.add(BatchNormalization())

# %%
add_model(model, 32, False, True)

# %%
add_model(model, 32, True)
add_model(model, 64, False)
add_model(model, 64, True)
add_model(model, 128, False)
add_model(model, 128, True)
add_model(model, 256, False)
add_model(model, 256, True)
add_model(model, 512, False)
add_model(model, 512, True)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))

# %%
model.compile(optimizer='Adam', loss='mse', metrics=['mae', 'acc'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5', monitor='val_mae', verbose=1, save_best_only=False)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.02, callbacks=[checkpointer])
# Out:
# Train on 1468 samples, validate on 30 samples
# Epoch 1/100
# 1468/1468 [==============================] - 425s 289ms/step - loss: 204.4703 - mae: 9.1447 - acc: 0.3631 - val_loss: 54352.5664 - val_mae: 211.0859 - val_acc: 0.3333
#
# Epoch 00001: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 2/100
# 1468/1468 [==============================] - 396s 270ms/step - loss: 31.2533 - mae: 4.3973 - acc: 0.4775 - val_loss: 858.3722 - val_mae: 22.5056 - val_acc: 0.7667
#
# Epoch 00002: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 3/100
# 1468/1468 [==============================] - 397s 271ms/step - loss: 25.7603 - mae: 3.9945 - acc: 0.5163 - val_loss: 273.1963 - val_mae: 12.2245 - val_acc: 0.7667
#
# Epoch 00003: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 4/100
# 1468/1468 [==============================] - 421s 287ms/step - loss: 22.9233 - mae: 3.7485 - acc: 0.5511 - val_loss: 168.7211 - val_mae: 9.9980 - val_acc: 0.7667
#
# Epoch 00004: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 5/100
# 1468/1468 [==============================] - 435s 297ms/step - loss: 22.0519 - mae: 3.6744 - acc: 0.5593 - val_loss: 187.1832 - val_mae: 11.7560 - val_acc: 0.6333
#
# Epoch 00005: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 6/100
# 1468/1468 [==============================] - 429s 292ms/step - loss: 20.6830 - mae: 3.5479 - acc: 0.5736 - val_loss: 119.3125 - val_mae: 8.6874 - val_acc: 0.7667
#
# Epoch 00006: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 7/100
# 1468/1468 [==============================] - 430s 293ms/step - loss: 18.9412 - mae: 3.3774 - acc: 0.5552 - val_loss: 175.4263 - val_mae: 11.6186 - val_acc: 0.7667
#
# Epoch 00007: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 8/100
# 1468/1468 [==============================] - 432s 295ms/step - loss: 18.1382 - mae: 3.3124 - acc: 0.6049 - val_loss: 150.2210 - val_mae: 10.3286 - val_acc: 0.7667
#
# Epoch 00008: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 9/100
# 1468/1468 [==============================] - 441s 301ms/step - loss: 16.6202 - mae: 3.1707 - acc: 0.5920 - val_loss: 124.6135 - val_mae: 8.8898 - val_acc: 0.7667
#
# Epoch 00009: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 10/100
# 1468/1468 [==============================] - 430s 293ms/step - loss: 16.9035 - mae: 3.1909 - acc: 0.6090 - val_loss: 98.9281 - val_mae: 8.4241 - val_acc: 0.7000
#
# Epoch 00010: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 11/100
# 1468/1468 [==============================] - 431s 293ms/step - loss: 15.3574 - mae: 3.0431 - acc: 0.6144 - val_loss: 206.8540 - val_mae: 12.6006 - val_acc: 0.7333
#
# Epoch 00011: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 12/100
# 1468/1468 [==============================] - 431s 294ms/step - loss: 16.9112 - mae: 3.2012 - acc: 0.6097 - val_loss: 92.6488 - val_mae: 7.9203 - val_acc: 0.7667
#
# Epoch 00012: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 13/100
# 1468/1468 [==============================] - 432s 294ms/step - loss: 16.2832 - mae: 3.1335 - acc: 0.6240 - val_loss: 207.0835 - val_mae: 12.8419 - val_acc: 0.7667
#
# Epoch 00013: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 14/100
# 1468/1468 [==============================] - 436s 297ms/step - loss: 14.7310 - mae: 2.9677 - acc: 0.6206 - val_loss: 149.5859 - val_mae: 11.0970 - val_acc: 0.7333
#
# Epoch 00014: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 15/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 13.9066 - mae: 2.8973 - acc: 0.6417 - val_loss: 160.3985 - val_mae: 11.5572 - val_acc: 0.7333
#
# Epoch 00015: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 16/100
# 1468/1468 [==============================] - 440s 300ms/step - loss: 13.1402 - mae: 2.8125 - acc: 0.6396 - val_loss: 135.2139 - val_mae: 10.5740 - val_acc: 0.7333
#
# Epoch 00016: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 17/100
# 1468/1468 [==============================] - 433s 295ms/step - loss: 13.1553 - mae: 2.8126 - acc: 0.6751 - val_loss: 178.0801 - val_mae: 12.3183 - val_acc: 0.7667
#
# Epoch 00017: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 18/100
# 1468/1468 [==============================] - 446s 304ms/step - loss: 12.2557 - mae: 2.7232 - acc: 0.6778 - val_loss: 159.4502 - val_mae: 11.7033 - val_acc: 0.7667
#
# Epoch 00018: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 19/100
# 1468/1468 [==============================] - 435s 296ms/step - loss: 10.8156 - mae: 2.5468 - acc: 0.6785 - val_loss: 137.0129 - val_mae: 10.8314 - val_acc: 0.7667
#
# Epoch 00019: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 20/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 10.7036 - mae: 2.5365 - acc: 0.6880 - val_loss: 155.8064 - val_mae: 11.5694 - val_acc: 0.8000
#
# Epoch 00020: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 21/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 11.5563 - mae: 2.6332 - acc: 0.6689 - val_loss: 119.8204 - val_mae: 9.9722 - val_acc: 0.7667
#
# Epoch 00021: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 22/100
# 1468/1468 [==============================] - 450s 307ms/step - loss: 11.8797 - mae: 2.6790 - acc: 0.6771 - val_loss: 53.2979 - val_mae: 6.4563 - val_acc: 0.8000
#
# Epoch 00022: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 23/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 10.5773 - mae: 2.5315 - acc: 0.6928 - val_loss: 89.8540 - val_mae: 8.6256 - val_acc: 0.8000
#
# Epoch 00023: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 24/100
# 1468/1468 [==============================] - 436s 297ms/step - loss: 10.8629 - mae: 2.5590 - acc: 0.7091 - val_loss: 53.0657 - val_mae: 6.4991 - val_acc: 0.7667
#
# Epoch 00024: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 25/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 10.2570 - mae: 2.4845 - acc: 0.7044 - val_loss: 66.4825 - val_mae: 7.3706 - val_acc: 0.8333
#
# Epoch 00025: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 26/100
# 1468/1468 [==============================] - 456s 310ms/step - loss: 11.0961 - mae: 2.5941 - acc: 0.6996 - val_loss: 43.6482 - val_mae: 5.8463 - val_acc: 0.7667
#
# Epoch 00026: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 27/100
# 1468/1468 [==============================] - 439s 299ms/step - loss: 9.8976 - mae: 2.4405 - acc: 0.6969 - val_loss: 50.9542 - val_mae: 6.3695 - val_acc: 0.7667
#
# Epoch 00027: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 28/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 9.7354 - mae: 2.4184 - acc: 0.6975 - val_loss: 77.2938 - val_mae: 7.8979 - val_acc: 0.8000
#
# Epoch 00028: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 29/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 9.0139 - mae: 2.3181 - acc: 0.7146 - val_loss: 46.3607 - val_mae: 6.1011 - val_acc: 0.7667
#
# Epoch 00029: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 30/100
# 1468/1468 [==============================] - 453s 309ms/step - loss: 8.6658 - mae: 2.2734 - acc: 0.7248 - val_loss: 73.2147 - val_mae: 7.9284 - val_acc: 0.8000
#
# Epoch 00030: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 31/100
# 1468/1468 [==============================] - 443s 302ms/step - loss: 9.3757 - mae: 2.3783 - acc: 0.7187 - val_loss: 48.4795 - val_mae: 6.0266 - val_acc: 0.7667
#
# Epoch 00031: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 32/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 7.9291 - mae: 2.1815 - acc: 0.7044 - val_loss: 20.4545 - val_mae: 3.7449 - val_acc: 0.8000
#
# Epoch 00032: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 33/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 7.9997 - mae: 2.1843 - acc: 0.7044 - val_loss: 36.4029 - val_mae: 5.2267 - val_acc: 0.8000
#
# Epoch 00033: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 34/100
# 1468/1468 [==============================] - 454s 309ms/step - loss: 8.2375 - mae: 2.2209 - acc: 0.7268 - val_loss: 45.3561 - val_mae: 5.9232 - val_acc: 0.7333
#
# Epoch 00034: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 35/100
# 1468/1468 [==============================] - 441s 300ms/step - loss: 9.4193 - mae: 2.3764 - acc: 0.7193 - val_loss: 59.2285 - val_mae: 6.9424 - val_acc: 0.7667
#
# Epoch 00035: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 36/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 7.7515 - mae: 2.1595 - acc: 0.7214 - val_loss: 37.3094 - val_mae: 5.3907 - val_acc: 0.7667
#
# Epoch 00036: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 37/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 7.7988 - mae: 2.1557 - acc: 0.7153 - val_loss: 27.1411 - val_mae: 4.4749 - val_acc: 0.7667
#
# Epoch 00037: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 38/100
# 1468/1468 [==============================] - 444s 303ms/step - loss: 6.8721 - mae: 2.0270 - acc: 0.7309 - val_loss: 26.4630 - val_mae: 4.4061 - val_acc: 0.8000
#
# Epoch 00038: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 39/100
# 1468/1468 [==============================] - 439s 299ms/step - loss: 7.2424 - mae: 2.0863 - acc: 0.7425 - val_loss: 20.7629 - val_mae: 3.9275 - val_acc: 0.8333
#
# Epoch 00039: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 40/100
# 1468/1468 [==============================] - 443s 302ms/step - loss: 7.1588 - mae: 2.0683 - acc: 0.7371 - val_loss: 20.1191 - val_mae: 3.7821 - val_acc: 0.8333
#
# Epoch 00040: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 41/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 6.7193 - mae: 2.0033 - acc: 0.7371 - val_loss: 19.6800 - val_mae: 3.6598 - val_acc: 0.8333
#
# Epoch 00041: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 42/100
# 1468/1468 [==============================] - 457s 311ms/step - loss: 6.6101 - mae: 1.9901 - acc: 0.7364 - val_loss: 28.9853 - val_mae: 4.8412 - val_acc: 0.8333
#
# Epoch 00042: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 43/100
# 1468/1468 [==============================] - 444s 302ms/step - loss: 6.8017 - mae: 2.0078 - acc: 0.7377 - val_loss: 18.8238 - val_mae: 3.6884 - val_acc: 0.9000
#
# Epoch 00043: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 44/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 9.9909 - mae: 2.4369 - acc: 0.7323 - val_loss: 21.2735 - val_mae: 3.8846 - val_acc: 0.8000
#
# Epoch 00044: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 45/100
# 1468/1468 [==============================] - 445s 303ms/step - loss: 7.7375 - mae: 2.1477 - acc: 0.7337 - val_loss: 22.5508 - val_mae: 4.0150 - val_acc: 0.7333
#
# Epoch 00045: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 46/100
# 1468/1468 [==============================] - 452s 308ms/step - loss: 6.7906 - mae: 2.0115 - acc: 0.7316 - val_loss: 21.0565 - val_mae: 3.8225 - val_acc: 0.8000
#
# Epoch 00046: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 47/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 7.9639 - mae: 2.1674 - acc: 0.7541 - val_loss: 7.0113 - val_mae: 2.0317 - val_acc: 0.8000
#
# Epoch 00047: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 48/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 6.8839 - mae: 2.0273 - acc: 0.7439 - val_loss: 13.1225 - val_mae: 2.9331 - val_acc: 0.8667
#
# Epoch 00048: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 49/100
# 1468/1468 [==============================] - 440s 300ms/step - loss: 6.8978 - mae: 2.0317 - acc: 0.7718 - val_loss: 13.8202 - val_mae: 2.9331 - val_acc: 0.8333
#
# Epoch 00049: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 50/100
# 1468/1468 [==============================] - 446s 304ms/step - loss: 6.0595 - mae: 1.8955 - acc: 0.7493 - val_loss: 22.6836 - val_mae: 3.9892 - val_acc: 0.8000
#
# Epoch 00050: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 51/100
# 1468/1468 [==============================] - 432s 295ms/step - loss: 6.1315 - mae: 1.8947 - acc: 0.7500 - val_loss: 20.7593 - val_mae: 3.8658 - val_acc: 0.8000
#
# Epoch 00051: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 52/100
# 1468/1468 [==============================] - 433s 295ms/step - loss: 6.0351 - mae: 1.9016 - acc: 0.7589 - val_loss: 15.0307 - val_mae: 3.0637 - val_acc: 0.8000
#
# Epoch 00052: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 53/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 6.1984 - mae: 1.9186 - acc: 0.7575 - val_loss: 11.2662 - val_mae: 2.7991 - val_acc: 0.8000
#
# Epoch 00053: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 54/100
# 1468/1468 [==============================] - 438s 299ms/step - loss: 6.5303 - mae: 1.9540 - acc: 0.7466 - val_loss: 9.5756 - val_mae: 2.4525 - val_acc: 0.8333
#
# Epoch 00054: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 55/100
# 1468/1468 [==============================] - 429s 292ms/step - loss: 6.5606 - mae: 1.9782 - acc: 0.7554 - val_loss: 10.4965 - val_mae: 2.3815 - val_acc: 0.8333
#
# Epoch 00055: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 56/100
# 1468/1468 [==============================] - 430s 293ms/step - loss: 6.1631 - mae: 1.9080 - acc: 0.7616 - val_loss: 12.6208 - val_mae: 2.8225 - val_acc: 0.8333
#
# Epoch 00056: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 57/100
# 1468/1468 [==============================] - 436s 297ms/step - loss: 7.8091 - mae: 2.1506 - acc: 0.7691 - val_loss: 23.1312 - val_mae: 3.9043 - val_acc: 0.8000
#
# Epoch 00057: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 58/100
# 1468/1468 [==============================] - 443s 302ms/step - loss: 5.6332 - mae: 1.8319 - acc: 0.7779 - val_loss: 9.7431 - val_mae: 2.5823 - val_acc: 0.7667
#
# Epoch 00058: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 59/100
# 1468/1468 [==============================] - 432s 294ms/step - loss: 6.3019 - mae: 1.9294 - acc: 0.7786 - val_loss: 18.3567 - val_mae: 3.4969 - val_acc: 0.8333
#
# Epoch 00059: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 60/100
# 1468/1468 [==============================] - 432s 294ms/step - loss: 5.6057 - mae: 1.8258 - acc: 0.7602 - val_loss: 9.9941 - val_mae: 2.4008 - val_acc: 0.7333
#
# Epoch 00060: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 61/100
# 1468/1468 [==============================] - 431s 294ms/step - loss: 6.6738 - mae: 1.9872 - acc: 0.7847 - val_loss: 5.3286 - val_mae: 1.8529 - val_acc: 0.8333
#
# Epoch 00061: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 62/100
# 1468/1468 [==============================] - 431s 293ms/step - loss: 6.6062 - mae: 1.9779 - acc: 0.7759 - val_loss: 7.9574 - val_mae: 2.0581 - val_acc: 0.7667
#
# Epoch 00062: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 63/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 5.5470 - mae: 1.8074 - acc: 0.7759 - val_loss: 12.9523 - val_mae: 2.8962 - val_acc: 0.8000
#
# Epoch 00063: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 64/100
# 1468/1468 [==============================] - 435s 296ms/step - loss: 5.2588 - mae: 1.7609 - acc: 0.7738 - val_loss: 17.4097 - val_mae: 3.4436 - val_acc: 0.8667
#
# Epoch 00064: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 65/100
# 1468/1468 [==============================] - 430s 293ms/step - loss: 5.0386 - mae: 1.7235 - acc: 0.7766 - val_loss: 13.4752 - val_mae: 3.0636 - val_acc: 0.9000
#
# Epoch 00065: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 66/100
# 1468/1468 [==============================] - 416s 284ms/step - loss: 7.2257 - mae: 2.0774 - acc: 0.7875 - val_loss: 9.7300 - val_mae: 2.3305 - val_acc: 0.7000
#
# Epoch 00066: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 67/100
# 1468/1468 [==============================] - 429s 292ms/step - loss: 7.2337 - mae: 2.0814 - acc: 0.7807 - val_loss: 8.6085 - val_mae: 2.2945 - val_acc: 0.8333
#
# Epoch 00067: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 68/100
# 1468/1468 [==============================] - 413s 281ms/step - loss: 6.0594 - mae: 1.8999 - acc: 0.7650 - val_loss: 5.4789 - val_mae: 1.7630 - val_acc: 0.9000
#
# Epoch 00068: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 69/100
# 1468/1468 [==============================] - 416s 283ms/step - loss: 5.3160 - mae: 1.7745 - acc: 0.7582 - val_loss: 7.6377 - val_mae: 2.0873 - val_acc: 0.7667
#
# Epoch 00069: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 70/100
# 1468/1468 [==============================] - 419s 285ms/step - loss: 6.2902 - mae: 1.9299 - acc: 0.7807 - val_loss: 19.9674 - val_mae: 3.7605 - val_acc: 0.8333
#
# Epoch 00070: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 71/100
# 1468/1468 [==============================] - 420s 286ms/step - loss: 6.0398 - mae: 1.8994 - acc: 0.7684 - val_loss: 11.2374 - val_mae: 2.6929 - val_acc: 0.8333
#
# Epoch 00071: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 72/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 4.8479 - mae: 1.6859 - acc: 0.7807 - val_loss: 6.1615 - val_mae: 1.9351 - val_acc: 0.8000
#
# Epoch 00072: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 73/100
# 1468/1468 [==============================] - 400s 273ms/step - loss: 4.8006 - mae: 1.6939 - acc: 0.7956 - val_loss: 15.8639 - val_mae: 3.4270 - val_acc: 0.8333
#
# Epoch 00073: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 74/100
# 1468/1468 [==============================] - 434s 296ms/step - loss: 5.0177 - mae: 1.7191 - acc: 0.7820 - val_loss: 6.0512 - val_mae: 1.8453 - val_acc: 0.9000
#
# Epoch 00074: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 75/100
# 1468/1468 [==============================] - 449s 306ms/step - loss: 4.9292 - mae: 1.7117 - acc: 0.7745 - val_loss: 21.9450 - val_mae: 4.0709 - val_acc: 0.8333
#
# Epoch 00075: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 76/100
# 1468/1468 [==============================] - 427s 291ms/step - loss: 7.3796 - mae: 2.0929 - acc: 0.7956 - val_loss: 10.3325 - val_mae: 2.5626 - val_acc: 0.7667
#
# Epoch 00076: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 77/100
# 1468/1468 [==============================] - 449s 306ms/step - loss: 5.9265 - mae: 1.8831 - acc: 0.7813 - val_loss: 4.7525 - val_mae: 1.5283 - val_acc: 0.8000
#
# Epoch 00077: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 78/100
# 1468/1468 [==============================] - 434s 296ms/step - loss: 5.5641 - mae: 1.8207 - acc: 0.7895 - val_loss: 11.1174 - val_mae: 2.6975 - val_acc: 0.8333
#
# Epoch 00078: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 79/100
# 1468/1468 [==============================] - 445s 303ms/step - loss: 5.6518 - mae: 1.8335 - acc: 0.7936 - val_loss: 7.0304 - val_mae: 2.1633 - val_acc: 0.8000
#
# Epoch 00079: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 80/100
# 1468/1468 [==============================] - 451s 307ms/step - loss: 4.7922 - mae: 1.6822 - acc: 0.7861 - val_loss: 24.1988 - val_mae: 4.4530 - val_acc: 0.8333
#
# Epoch 00080: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 81/100
# 1468/1468 [==============================] - 445s 303ms/step - loss: 4.6530 - mae: 1.6628 - acc: 0.8018 - val_loss: 8.8117 - val_mae: 2.3668 - val_acc: 0.8000
#
# Epoch 00081: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 82/100
# 1468/1468 [==============================] - 428s 291ms/step - loss: 4.7840 - mae: 1.6845 - acc: 0.8045 - val_loss: 13.9526 - val_mae: 3.1128 - val_acc: 0.8000
#
# Epoch 00082: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 83/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 5.2097 - mae: 1.7604 - acc: 0.8045 - val_loss: 12.2995 - val_mae: 2.8584 - val_acc: 0.6333
#
# Epoch 00083: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 84/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 5.4694 - mae: 1.8077 - acc: 0.7990 - val_loss: 10.7352 - val_mae: 2.6816 - val_acc: 0.8333
#
# Epoch 00084: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 85/100
# 1468/1468 [==============================] - 431s 294ms/step - loss: 4.8196 - mae: 1.6843 - acc: 0.8072 - val_loss: 8.8724 - val_mae: 2.3030 - val_acc: 0.7333
#
# Epoch 00085: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 86/100
# 1468/1468 [==============================] - 436s 297ms/step - loss: 4.8054 - mae: 1.6904 - acc: 0.7841 - val_loss: 7.0696 - val_mae: 2.0816 - val_acc: 0.8667
#
# Epoch 00086: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 87/100
# 1468/1468 [==============================] - 443s 302ms/step - loss: 4.9952 - mae: 1.7115 - acc: 0.8011 - val_loss: 12.8804 - val_mae: 3.0400 - val_acc: 0.7667
#
# Epoch 00087: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 88/100
# 1468/1468 [==============================] - 498s 340ms/step - loss: 5.2621 - mae: 1.7545 - acc: 0.8059 - val_loss: 12.7001 - val_mae: 2.9187 - val_acc: 0.7333
#
# Epoch 00088: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 89/100
# 1468/1468 [==============================] - 464s 316ms/step - loss: 4.7839 - mae: 1.6725 - acc: 0.7929 - val_loss: 13.7886 - val_mae: 3.1431 - val_acc: 0.6333
#
# Epoch 00089: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 90/100
# 1468/1468 [==============================] - 547s 372ms/step - loss: 5.4012 - mae: 1.7924 - acc: 0.8147 - val_loss: 6.1566 - val_mae: 1.8098 - val_acc: 0.8333
#
# Epoch 00090: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 91/100
# 1468/1468 [==============================] - 507s 346ms/step - loss: 5.1176 - mae: 1.7414 - acc: 0.8045 - val_loss: 25.0012 - val_mae: 4.4784 - val_acc: 0.7333
#
# Epoch 00091: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 92/100
# 1468/1468 [==============================] - 435s 297ms/step - loss: 5.4969 - mae: 1.8090 - acc: 0.8270 - val_loss: 9.1143 - val_mae: 2.3645 - val_acc: 0.8667
#
# Epoch 00092: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 93/100
# 1468/1468 [==============================] - 434s 296ms/step - loss: 4.3204 - mae: 1.5918 - acc: 0.8079 - val_loss: 6.1545 - val_mae: 1.8639 - val_acc: 0.8000
#
# Epoch 00093: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 94/100
# 1468/1468 [==============================] - 435s 296ms/step - loss: 4.6967 - mae: 1.6626 - acc: 0.7997 - val_loss: 19.9084 - val_mae: 3.8872 - val_acc: 0.7667
#
# Epoch 00094: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 95/100
# 1468/1468 [==============================] - 455s 310ms/step - loss: 5.2795 - mae: 1.7660 - acc: 0.8038 - val_loss: 7.6806 - val_mae: 2.1448 - val_acc: 0.8000
#
# Epoch 00095: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 96/100
# 1468/1468 [==============================] - 476s 324ms/step - loss: 4.3882 - mae: 1.6084 - acc: 0.8168 - val_loss: 10.0990 - val_mae: 2.4917 - val_acc: 0.7333
#
# Epoch 00096: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 97/100
# 1468/1468 [==============================] - 589s 401ms/step - loss: 4.5662 - mae: 1.6436 - acc: 0.8072 - val_loss: 20.0579 - val_mae: 3.8453 - val_acc: 0.8000
#
# Epoch 00097: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 98/100
# 1468/1468 [==============================] - 619s 421ms/step - loss: 4.9198 - mae: 1.7141 - acc: 0.8065 - val_loss: 10.8060 - val_mae: 2.7063 - val_acc: 0.8667
#
# Epoch 00098: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 99/100
# 1468/1468 [==============================] - 551s 375ms/step - loss: 4.6502 - mae: 1.6722 - acc: 0.8093 - val_loss: 14.9905 - val_mae: 3.2617 - val_acc: 0.7000
#
# Epoch 00099: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5
# Epoch 100/100
# 1468/1468 [==============================] - 470s 320ms/step - loss: 5.5028 - mae: 1.8063 - acc: 0.8011 - val_loss: 14.6578 - val_mae: 3.1737 - val_acc: 0.6333
#
# Epoch 00100: saving model to layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
train_predicts = model.predict(X_train)

# %%
plt.imshow(X_train[0].reshape((96,96)), cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[0][i-1], train_predicts[0][i], 'ro')
    plt.plot(y_train[0][i-1], y_train[0][i], 'x', color='green')

plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'], linewidth=2, label="train")
plt.plot(history.history['val_loss'], linewidth=2, label="val ")
plt.legend()
plt.title('Loss vs Epoch')
plt.grid()
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("Log Loss")
fig= plt.figure(figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['mae'], linewidth=2)
plt.plot(history.history['val_mae'], linewidth=2)
plt.title('Mean Absolute Error vs Epoch')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epochs')
plt.yscale("log")
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['acc'], linewidth=2)
plt.plot(history.history['val_acc'], linewidth=2)
plt.title('Accuracy vs Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
predict = model.predict(test_X)

# %%
header = list(y.columns)

# %%
df_predict = pd.DataFrame(predict, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = df_predict.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
SampleSubmission.to_csv('submission_100_epochs_kernel5x5_fext_dropout=0p2.csv', index=False)

# %%
pd.DataFrame(history.history.items()).to_csv('history_submission_100_epochs_kernel5x5_fext_dropout=0p2.csv', index=False)
