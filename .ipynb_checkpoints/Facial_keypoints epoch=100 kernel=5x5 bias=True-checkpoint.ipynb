# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
import random

import sys
import matplotlib
import sklearn
import numpy
import keras
import tensorflow as tf 
from keras.layers import Dense, Flatten, BatchNormalization, Dropout, Convolution2D, MaxPool2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import Callback
# Out:
# Using TensorFlow backend.

# %%
print('Versão Python ', sys.version)
print('Versão Numpy ', numpy.version.version)
print('Versão Pandas ', pd.__version__)
print('Versão Matplotlib ', matplotlib.__version__)
print('Versão Sklearn ', sklearn.__version__)
print('Versão Keras', keras.__version__)
print('Versão TensorFlow', tf.__version__)
# Out:
# Versão Python  3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:18:16) [MSC v.1916 64 bit (AMD64)]
# Versão Numpy  1.17.4
# Versão Pandas  0.25.3
# Versão Matplotlib  3.1.2
# Versão Sklearn  0.22.1
# Versão Keras 2.3.1
# Versão TensorFlow 2.0.0

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
training = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %%
training = training.dropna()

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)

# %%
y = training.drop(['Image'], axis=1)

# %%
y_ndarray = y.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_ndarray, test_size=0.3, random_state=42)

# %%
model = Sequential()

# %%
def add_model(model, filters, maxpooling, *inputshape):   
    if inputshape:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False, input_shape=(96,96,1)))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
    else:
      if maxpooling:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
        model.add(MaxPool2D(pool_size=(2, 2)))
      else:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())

# %%
add_model(model, 32, False, True)

# %%
add_model(model, 32, True)
add_model(model, 64, False)
add_model(model, 64, True)
add_model(model, 128, False)
add_model(model, 128, True)
add_model(model, 256, False)
add_model(model, 256, True)
add_model(model, 512, False)
add_model(model, 512, True)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))

# %%
model.compile(optimizer='Adam', loss='mse', metrics=['mae', 'acc'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'layer10_epoc100_kernel5p5_usebiasTrue.hdf5', monitor='val_mae', verbose=1, save_best_only=False)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.02, callbacks=[checkpointer])
# Out:
# Train on 1468 samples, validate on 30 samples
# Epoch 1/100
# 1468/1468 [==============================] - 397s 270ms/step - loss: 186.8625 - mae: 8.5412 - acc: 0.4401 - val_loss: 17548.2930 - val_mae: 115.0894 - val_acc: 0.7667
#
# Epoch 00001: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 2/100
# 1468/1468 [==============================] - 395s 269ms/step - loss: 27.9809 - mae: 4.1624 - acc: 0.4830 - val_loss: 1476.3845 - val_mae: 34.9757 - val_acc: 0.7667
#
# Epoch 00002: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 3/100
# 1468/1468 [==============================] - 397s 271ms/step - loss: 22.8115 - mae: 3.7516 - acc: 0.5177 - val_loss: 175.3600 - val_mae: 12.2277 - val_acc: 0.7333
#
# Epoch 00003: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 4/100
# 1468/1468 [==============================] - 389s 265ms/step - loss: 20.3185 - mae: 3.5366 - acc: 0.5640 - val_loss: 34.0939 - val_mae: 5.1400 - val_acc: 0.8667
#
# Epoch 00004: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 5/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 18.2607 - mae: 3.3544 - acc: 0.6001 - val_loss: 11.1340 - val_mae: 2.7418 - val_acc: 0.8000
#
# Epoch 00005: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 6/100
# 1468/1468 [==============================] - 387s 264ms/step - loss: 17.0312 - mae: 3.2271 - acc: 0.5668 - val_loss: 6.8126 - val_mae: 2.0029 - val_acc: 0.7667
#
# Epoch 00006: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 7/100
# 1468/1468 [==============================] - 399s 272ms/step - loss: 14.7263 - mae: 2.9969 - acc: 0.6049 - val_loss: 10.6400 - val_mae: 2.7322 - val_acc: 0.7667
#
# Epoch 00007: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 8/100
# 1468/1468 [==============================] - 387s 264ms/step - loss: 13.7635 - mae: 2.9017 - acc: 0.6076 - val_loss: 6.2875 - val_mae: 1.8467 - val_acc: 0.7667
#
# Epoch 00008: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 9/100
# 1468/1468 [==============================] - 387s 264ms/step - loss: 12.9132 - mae: 2.8130 - acc: 0.6247 - val_loss: 4.8530 - val_mae: 1.6386 - val_acc: 0.8000
#
# Epoch 00009: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 10/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 13.5973 - mae: 2.8749 - acc: 0.6444 - val_loss: 17.7592 - val_mae: 3.6973 - val_acc: 0.7667
#
# Epoch 00010: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 11/100
# 1468/1468 [==============================] - 384s 261ms/step - loss: 15.5563 - mae: 3.1003 - acc: 0.6567 - val_loss: 5.3150 - val_mae: 1.6464 - val_acc: 0.7333
#
# Epoch 00011: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 12/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 13.6275 - mae: 2.8789 - acc: 0.6417 - val_loss: 5.9250 - val_mae: 1.7825 - val_acc: 0.7667
#
# Epoch 00012: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 13/100
# 1468/1468 [==============================] - 384s 262ms/step - loss: 10.7359 - mae: 2.5580 - acc: 0.6383 - val_loss: 4.3980 - val_mae: 1.5333 - val_acc: 0.7667
#
# Epoch 00013: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 14/100
# 1468/1468 [==============================] - 387s 263ms/step - loss: 10.2595 - mae: 2.4802 - acc: 0.6485 - val_loss: 4.5426 - val_mae: 1.5420 - val_acc: 0.8000
#
# Epoch 00014: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 15/100
# 1468/1468 [==============================] - 383s 261ms/step - loss: 11.0598 - mae: 2.5892 - acc: 0.6703 - val_loss: 4.6907 - val_mae: 1.6853 - val_acc: 0.8667
#
# Epoch 00015: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 16/100
# 1468/1468 [==============================] - 383s 261ms/step - loss: 10.8972 - mae: 2.5676 - acc: 0.6676 - val_loss: 3.9857 - val_mae: 1.4883 - val_acc: 0.7667
#
# Epoch 00016: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 17/100
# 1468/1468 [==============================] - 397s 270ms/step - loss: 9.6820 - mae: 2.4162 - acc: 0.6928 - val_loss: 15.5254 - val_mae: 3.3686 - val_acc: 0.8000
#
# Epoch 00017: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 18/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 10.4764 - mae: 2.5144 - acc: 0.6785 - val_loss: 3.9122 - val_mae: 1.4810 - val_acc: 0.7333
#
# Epoch 00018: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 19/100
# 1468/1468 [==============================] - 384s 262ms/step - loss: 9.1675 - mae: 2.3541 - acc: 0.6676 - val_loss: 3.9282 - val_mae: 1.4215 - val_acc: 0.6667
#
# Epoch 00019: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 20/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 8.5824 - mae: 2.2786 - acc: 0.6860 - val_loss: 16.0116 - val_mae: 3.2005 - val_acc: 0.7333
#
# Epoch 00020: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 21/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 8.8012 - mae: 2.3025 - acc: 0.7064 - val_loss: 4.5727 - val_mae: 1.6621 - val_acc: 0.7667
#
# Epoch 00021: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 22/100
# 1468/1468 [==============================] - 383s 261ms/step - loss: 8.0477 - mae: 2.1888 - acc: 0.7200 - val_loss: 6.5270 - val_mae: 2.0697 - val_acc: 0.7333
#
# Epoch 00022: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 23/100
# 1468/1468 [==============================] - 388s 264ms/step - loss: 9.1129 - mae: 2.3453 - acc: 0.6989 - val_loss: 3.2140 - val_mae: 1.3080 - val_acc: 0.8000
#
# Epoch 00023: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 24/100
# 1468/1468 [==============================] - 442s 301ms/step - loss: 8.0408 - mae: 2.1912 - acc: 0.7119 - val_loss: 7.4746 - val_mae: 2.3228 - val_acc: 0.7667
#
# Epoch 00024: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 25/100
# 1468/1468 [==============================] - 499s 340ms/step - loss: 8.4054 - mae: 2.2469 - acc: 0.7173 - val_loss: 3.1913 - val_mae: 1.2729 - val_acc: 0.8667
#
# Epoch 00025: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 26/100
# 1468/1468 [==============================] - 455s 310ms/step - loss: 7.8654 - mae: 2.1820 - acc: 0.7193 - val_loss: 6.2663 - val_mae: 1.9733 - val_acc: 0.7667
#
# Epoch 00026: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 27/100
# 1468/1468 [==============================] - 414s 282ms/step - loss: 7.2626 - mae: 2.0831 - acc: 0.7255 - val_loss: 10.1764 - val_mae: 2.6239 - val_acc: 0.7333
#
# Epoch 00027: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 28/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 7.4799 - mae: 2.1256 - acc: 0.7228 - val_loss: 2.8324 - val_mae: 1.2363 - val_acc: 0.8000
#
# Epoch 00028: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 29/100
# 1468/1468 [==============================] - 390s 265ms/step - loss: 9.4101 - mae: 2.3681 - acc: 0.7289 - val_loss: 3.3175 - val_mae: 1.2888 - val_acc: 0.8000
#
# Epoch 00029: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 30/100
# 1468/1468 [==============================] - 400s 272ms/step - loss: 7.5005 - mae: 2.1162 - acc: 0.7302 - val_loss: 6.0298 - val_mae: 1.9296 - val_acc: 0.7333
#
# Epoch 00030: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 31/100
# 1468/1468 [==============================] - 401s 273ms/step - loss: 6.9766 - mae: 2.0460 - acc: 0.7146 - val_loss: 3.4201 - val_mae: 1.2996 - val_acc: 0.7667
#
# Epoch 00031: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 32/100
# 1468/1468 [==============================] - 405s 276ms/step - loss: 7.7932 - mae: 2.1696 - acc: 0.7439 - val_loss: 3.6661 - val_mae: 1.2981 - val_acc: 0.7667
#
# Epoch 00032: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 33/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 6.8425 - mae: 2.0200 - acc: 0.7221 - val_loss: 5.0907 - val_mae: 1.8672 - val_acc: 0.7333
#
# Epoch 00033: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 34/100
# 1468/1468 [==============================] - 407s 278ms/step - loss: 7.0533 - mae: 2.0565 - acc: 0.7575 - val_loss: 4.4683 - val_mae: 1.6653 - val_acc: 0.8000
#
# Epoch 00034: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 35/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 6.3432 - mae: 1.9430 - acc: 0.7589 - val_loss: 5.5559 - val_mae: 1.9349 - val_acc: 0.8000
#
# Epoch 00035: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 36/100
# 1468/1468 [==============================] - 393s 268ms/step - loss: 9.2075 - mae: 2.3539 - acc: 0.7425 - val_loss: 9.4041 - val_mae: 2.6279 - val_acc: 0.8000
#
# Epoch 00036: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 37/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 7.1633 - mae: 2.0534 - acc: 0.7262 - val_loss: 4.2174 - val_mae: 1.6609 - val_acc: 0.8667
#
# Epoch 00037: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 38/100
# 1468/1468 [==============================] - 389s 265ms/step - loss: 6.8846 - mae: 2.0286 - acc: 0.7548 - val_loss: 2.8390 - val_mae: 1.2313 - val_acc: 0.7667
#
# Epoch 00038: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 39/100
# 1468/1468 [==============================] - 400s 273ms/step - loss: 6.7149 - mae: 1.9890 - acc: 0.7725 - val_loss: 3.8329 - val_mae: 1.5433 - val_acc: 0.8000
#
# Epoch 00039: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 40/100
# 1468/1468 [==============================] - 395s 269ms/step - loss: 6.9613 - mae: 2.0463 - acc: 0.7527 - val_loss: 3.1321 - val_mae: 1.2607 - val_acc: 0.8000
#
# Epoch 00040: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 41/100
# 1468/1468 [==============================] - 391s 267ms/step - loss: 6.9480 - mae: 2.0272 - acc: 0.7459 - val_loss: 2.9472 - val_mae: 1.2515 - val_acc: 0.8667
#
# Epoch 00041: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 42/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 6.7869 - mae: 2.0053 - acc: 0.7459 - val_loss: 2.7911 - val_mae: 1.2675 - val_acc: 0.8333
#
# Epoch 00042: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 43/100
# 1468/1468 [==============================] - 403s 274ms/step - loss: 5.9399 - mae: 1.8670 - acc: 0.7657 - val_loss: 3.6834 - val_mae: 1.4300 - val_acc: 0.8000
#
# Epoch 00043: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 44/100
# 1468/1468 [==============================] - 389s 265ms/step - loss: 5.5678 - mae: 1.8178 - acc: 0.7602 - val_loss: 2.9401 - val_mae: 1.2673 - val_acc: 0.8000
#
# Epoch 00044: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 45/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 5.7144 - mae: 1.8412 - acc: 0.7766 - val_loss: 4.9158 - val_mae: 1.8321 - val_acc: 0.8333
#
# Epoch 00045: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 46/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 5.4616 - mae: 1.8012 - acc: 0.7766 - val_loss: 4.8138 - val_mae: 1.8072 - val_acc: 0.7333
#
# Epoch 00046: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 47/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 5.1066 - mae: 1.7399 - acc: 0.7752 - val_loss: 3.2337 - val_mae: 1.3289 - val_acc: 0.8667
#
# Epoch 00047: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 48/100
# 1468/1468 [==============================] - 401s 273ms/step - loss: 5.3709 - mae: 1.7744 - acc: 0.7677 - val_loss: 5.2819 - val_mae: 1.9102 - val_acc: 0.8333
#
# Epoch 00048: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 49/100
# 1468/1468 [==============================] - 390s 265ms/step - loss: 5.5295 - mae: 1.8112 - acc: 0.7895 - val_loss: 2.7986 - val_mae: 1.2321 - val_acc: 0.7333
#
# Epoch 00049: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 50/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 4.6909 - mae: 1.6638 - acc: 0.7888 - val_loss: 3.4752 - val_mae: 1.3198 - val_acc: 0.8333
#
# Epoch 00050: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 51/100
# 1468/1468 [==============================] - 390s 266ms/step - loss: 6.2209 - mae: 1.9222 - acc: 0.7841 - val_loss: 3.3385 - val_mae: 1.3524 - val_acc: 0.7667
#
# Epoch 00051: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 52/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 5.5615 - mae: 1.8181 - acc: 0.7725 - val_loss: 4.5460 - val_mae: 1.7414 - val_acc: 0.8333
#
# Epoch 00052: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 53/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 7.0718 - mae: 2.0371 - acc: 0.7888 - val_loss: 10.3041 - val_mae: 2.5987 - val_acc: 0.7333
#
# Epoch 00053: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 54/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 5.2349 - mae: 1.7677 - acc: 0.7909 - val_loss: 2.9459 - val_mae: 1.2283 - val_acc: 0.7333
#
# Epoch 00054: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 55/100
# 1468/1468 [==============================] - 387s 263ms/step - loss: 5.2301 - mae: 1.7585 - acc: 0.7881 - val_loss: 2.4672 - val_mae: 1.1147 - val_acc: 0.7667
#
# Epoch 00055: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 56/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 5.7234 - mae: 1.8320 - acc: 0.7786 - val_loss: 2.4753 - val_mae: 1.1065 - val_acc: 0.8333
#
# Epoch 00056: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 57/100
# 1468/1468 [==============================] - 399s 272ms/step - loss: 4.9975 - mae: 1.7125 - acc: 0.7922 - val_loss: 5.7625 - val_mae: 1.8613 - val_acc: 0.8333
#
# Epoch 00057: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 58/100
# 1468/1468 [==============================] - 387s 263ms/step - loss: 4.7010 - mae: 1.6642 - acc: 0.8018 - val_loss: 3.6340 - val_mae: 1.4957 - val_acc: 0.7000
#
# Epoch 00058: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 59/100
# 1468/1468 [==============================] - 391s 267ms/step - loss: 4.7650 - mae: 1.6765 - acc: 0.7943 - val_loss: 2.9312 - val_mae: 1.2983 - val_acc: 0.8000
#
# Epoch 00059: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 60/100
# 1468/1468 [==============================] - 390s 265ms/step - loss: 5.1265 - mae: 1.7362 - acc: 0.8045 - val_loss: 3.1942 - val_mae: 1.3666 - val_acc: 0.7667
#
# Epoch 00060: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 61/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 4.6381 - mae: 1.6483 - acc: 0.8079 - val_loss: 2.2256 - val_mae: 1.0407 - val_acc: 0.8000
#
# Epoch 00061: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 62/100
# 1468/1468 [==============================] - 404s 275ms/step - loss: 4.5113 - mae: 1.6242 - acc: 0.8045 - val_loss: 3.9689 - val_mae: 1.4989 - val_acc: 0.7667
#
# Epoch 00062: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 63/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 4.8983 - mae: 1.6920 - acc: 0.7997 - val_loss: 4.1106 - val_mae: 1.6050 - val_acc: 0.7667
#
# Epoch 00063: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 64/100
# 1468/1468 [==============================] - 390s 266ms/step - loss: 4.5192 - mae: 1.6347 - acc: 0.7936 - val_loss: 2.7787 - val_mae: 1.1134 - val_acc: 0.8667
#
# Epoch 00064: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 65/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 6.4409 - mae: 1.9501 - acc: 0.8059 - val_loss: 2.5508 - val_mae: 1.1290 - val_acc: 0.8000
#
# Epoch 00065: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 66/100
# 1468/1468 [==============================] - 402s 274ms/step - loss: 4.3446 - mae: 1.6002 - acc: 0.8065 - val_loss: 3.8868 - val_mae: 1.5932 - val_acc: 0.8000
#
# Epoch 00066: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 67/100
# 1468/1468 [==============================] - 388s 264ms/step - loss: 4.8404 - mae: 1.6816 - acc: 0.8099 - val_loss: 4.9557 - val_mae: 1.8113 - val_acc: 0.8333
# Epoch 00067: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 68/100
# 1468/1468 [==============================] - 390s 266ms/step - loss: 4.7508 - mae: 1.6748 - acc: 0.8113 - val_loss: 5.0992 - val_mae: 1.8395 - val_acc: 0.7667
#
# Epoch 00068: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 69/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 4.3069 - mae: 1.5870 - acc: 0.8174 - val_loss: 3.5812 - val_mae: 1.3394 - val_acc: 0.8333
#
# Epoch 00069: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 70/100
# 1468/1468 [==============================] - 382s 260ms/step - loss: 4.6330 - mae: 1.6482 - acc: 0.7956 - val_loss: 3.1625 - val_mae: 1.3359 - val_acc: 0.7667
#
# Epoch 00070: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 71/100
# 1468/1468 [==============================] - 397s 271ms/step - loss: 4.9183 - mae: 1.7056 - acc: 0.8202 - val_loss: 4.7807 - val_mae: 1.7647 - val_acc: 0.7000
#
# Epoch 00071: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 72/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 4.3087 - mae: 1.5945 - acc: 0.8106 - val_loss: 3.8490 - val_mae: 1.4541 - val_acc: 0.8000
#
# Epoch 00072: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 73/100
# 1468/1468 [==============================] - 387s 263ms/step - loss: 4.3978 - mae: 1.6061 - acc: 0.8134 - val_loss: 3.2136 - val_mae: 1.2697 - val_acc: 0.8333
#
# Epoch 00073: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 74/100
# 1468/1468 [==============================] - 384s 261ms/step - loss: 4.8747 - mae: 1.7014 - acc: 0.8106 - val_loss: 5.5309 - val_mae: 1.7824 - val_acc: 0.8000
#
# Epoch 00074: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 75/100
# 1468/1468 [==============================] - 383s 261ms/step - loss: 4.3043 - mae: 1.5886 - acc: 0.8140 - val_loss: 3.7360 - val_mae: 1.4815 - val_acc: 0.7333
#
# Epoch 00075: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 76/100
# 1468/1468 [==============================] - 390s 266ms/step - loss: 4.1863 - mae: 1.5654 - acc: 0.8093 - val_loss: 3.6202 - val_mae: 1.5175 - val_acc: 0.7333
#
# Epoch 00076: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 77/100
# 1468/1468 [==============================] - 389s 265ms/step - loss: 4.4843 - mae: 1.6286 - acc: 0.8202 - val_loss: 2.7831 - val_mae: 1.2391 - val_acc: 0.8333
#
# Epoch 00077: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 78/100
# 1468/1468 [==============================] - 384s 261ms/step - loss: 4.3979 - mae: 1.6147 - acc: 0.7997 - val_loss: 2.7416 - val_mae: 1.1308 - val_acc: 0.8000
#
# Epoch 00078: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 79/100
# 1468/1468 [==============================] - 387s 264ms/step - loss: 5.3929 - mae: 1.7808 - acc: 0.8256 - val_loss: 2.3896 - val_mae: 1.0905 - val_acc: 0.7667
#
# Epoch 00079: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 80/100
# 1468/1468 [==============================] - 393s 268ms/step - loss: 4.8652 - mae: 1.7041 - acc: 0.8120 - val_loss: 4.8037 - val_mae: 1.7480 - val_acc: 0.8000
#
# Epoch 00080: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 81/100
# 1468/1468 [==============================] - 379s 258ms/step - loss: 5.6027 - mae: 1.8210 - acc: 0.8120 - val_loss: 11.0871 - val_mae: 2.8116 - val_acc: 0.6667
#
# Epoch 00081: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 82/100
# 1468/1468 [==============================] - 381s 260ms/step - loss: 4.4237 - mae: 1.6194 - acc: 0.8120 - val_loss: 2.9082 - val_mae: 1.2021 - val_acc: 0.6000
#
# Epoch 00082: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 83/100
# 1468/1468 [==============================] - 383s 261ms/step - loss: 7.0639 - mae: 2.0506 - acc: 0.7922 - val_loss: 7.2346 - val_mae: 2.2326 - val_acc: 0.9000
#
# Epoch 00083: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 84/100
# 1468/1468 [==============================] - 381s 260ms/step - loss: 4.5180 - mae: 1.6379 - acc: 0.8134 - val_loss: 11.9234 - val_mae: 3.0570 - val_acc: 0.8667
#
# Epoch 00084: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 85/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 3.9712 - mae: 1.5262 - acc: 0.8222 - val_loss: 7.4947 - val_mae: 2.3703 - val_acc: 0.7667
#
# Epoch 00085: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 86/100
# 1468/1468 [==============================] - 380s 259ms/step - loss: 4.0778 - mae: 1.5450 - acc: 0.8270 - val_loss: 4.2692 - val_mae: 1.6117 - val_acc: 0.7667
#
# Epoch 00086: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 87/100
# 1468/1468 [==============================] - 381s 260ms/step - loss: 4.1538 - mae: 1.5572 - acc: 0.8134 - val_loss: 3.0967 - val_mae: 1.2600 - val_acc: 0.7667
#
# Epoch 00087: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 88/100
# 1468/1468 [==============================] - 381s 259ms/step - loss: 3.7377 - mae: 1.4822 - acc: 0.8379 - val_loss: 2.2154 - val_mae: 1.0159 - val_acc: 0.7667
#
# Epoch 00088: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 89/100
# 1468/1468 [==============================] - 378s 258ms/step - loss: 3.7347 - mae: 1.4770 - acc: 0.8304 - val_loss: 3.7148 - val_mae: 1.4646 - val_acc: 0.8667
#
# Epoch 00089: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 90/100
# 1468/1468 [==============================] - 390s 266ms/step - loss: 4.2991 - mae: 1.5921 - acc: 0.8188 - val_loss: 4.9229 - val_mae: 1.8413 - val_acc: 0.7333
#
# Epoch 00090: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 91/100
# 1468/1468 [==============================] - 383s 261ms/step - loss: 3.7801 - mae: 1.4938 - acc: 0.8222 - val_loss: 2.1545 - val_mae: 0.9954 - val_acc: 0.8333
#
# Epoch 00091: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 92/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 3.9916 - mae: 1.5343 - acc: 0.8379 - val_loss: 3.7535 - val_mae: 1.4269 - val_acc: 0.6667
#
# Epoch 00092: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 93/100
# 1468/1468 [==============================] - 379s 258ms/step - loss: 3.7709 - mae: 1.4919 - acc: 0.8229 - val_loss: 2.5416 - val_mae: 1.1948 - val_acc: 0.8333
#
# Epoch 00093: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 94/100
# 1468/1468 [==============================] - 382s 260ms/step - loss: 4.4303 - mae: 1.6119 - acc: 0.8140 - val_loss: 3.7701 - val_mae: 1.5533 - val_acc: 0.7667
#
# Epoch 00094: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 95/100
# 1468/1468 [==============================] - 376s 256ms/step - loss: 3.6870 - mae: 1.4656 - acc: 0.8351 - val_loss: 3.3920 - val_mae: 1.3857 - val_acc: 0.7667
#
# Epoch 00095: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 96/100
# 1468/1468 [==============================] - 379s 258ms/step - loss: 3.9927 - mae: 1.5203 - acc: 0.8331 - val_loss: 9.4795 - val_mae: 2.6741 - val_acc: 0.7667
#
# Epoch 00096: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 97/100
# 1468/1468 [==============================] - 377s 257ms/step - loss: 6.0480 - mae: 1.9033 - acc: 0.8106 - val_loss: 4.9194 - val_mae: 1.7950 - val_acc: 0.8000
#
# Epoch 00097: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 98/100
# 1468/1468 [==============================] - 379s 258ms/step - loss: 4.1009 - mae: 1.5520 - acc: 0.8426 - val_loss: 2.9816 - val_mae: 1.2141 - val_acc: 0.7333
#
# Epoch 00098: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 99/100
# 1468/1468 [==============================] - 392s 267ms/step - loss: 5.1353 - mae: 1.7428 - acc: 0.8270 - val_loss: 2.4784 - val_mae: 1.1228 - val_acc: 0.7667
#
# Epoch 00099: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5
# Epoch 100/100
# 1468/1468 [==============================] - 379s 258ms/step - loss: 4.9965 - mae: 1.7310 - acc: 0.8045 - val_loss: 6.0672 - val_mae: 2.0438 - val_acc: 0.7667
#
# Epoch 00100: saving model to layer10_epoc100_kernel5p5_usebiasTrue.hdf5

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 6.907446094762499
# Test accuracy: 2.197155237197876

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
train_predicts = model.predict(X_train)

# %%
plt.imshow(X_train[0].reshape((96,96)), cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[0][i-1], train_predicts[0][i], 'ro')
    plt.plot(y_train[0][i-1], y_train[0][i], 'x', color='green')

plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'], linewidth=2, label="train")
plt.plot(history.history['val_loss'], linewidth=2, label="val ")
plt.legend()
plt.title('Loss vs Epoch')
plt.grid()
plt.yscale("log")
plt.xlabel("Epoch")
plt.ylabel("Log Loss")
fig= plt.figure(figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['mae'], linewidth=2)
plt.plot(history.history['val_mae'], linewidth=2)
plt.title('Mean Absolute Error vs Epoch')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epochs')
plt.yscale("log")
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['acc'], linewidth=2)
plt.plot(history.history['val_acc'], linewidth=2)
plt.title('Accuracy vs Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
predict = model.predict(test_X)

# %%
header = list(y.columns)

# %%
df_predict = pd.DataFrame(predict, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = df_predict.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
SampleSubmission.to_csv('submission_100_epochs_kernel5x5biastrue.csv', index=False)

# %%
pd.DataFrame(history.history.items()).to_csv('history_submission_100_epochs_kernel5x5biastrue.csv', index=False)
