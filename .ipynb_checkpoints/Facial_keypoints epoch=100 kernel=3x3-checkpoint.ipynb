# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
import random

import sys
import matplotlib
import sklearn
import numpy
import keras
import tensorflow as tf 
from keras.layers import Dense, Flatten, BatchNormalization, Dropout, Convolution2D, MaxPool2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import Callback

# %%
print('Versão Python ', sys.version)
print('Versão Numpy ', numpy.version.version)
print('Versão Pandas ', pd.__version__)
print('Versão Matplotlib ', matplotlib.__version__)
print('Versão Sklearn ', sklearn.__version__)
print('Versão Keras', keras.__version__)
print('Versão TensorFlow', tf.__version__)
# Out:
# Versão Python  3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:18:16) [MSC v.1916 64 bit (AMD64)]
# Versão Numpy  1.17.4
# Versão Pandas  0.25.3
# Versão Matplotlib  3.1.2
# Versão Sklearn  0.22.1
# Versão Keras 2.3.1
# Versão TensorFlow 2.0.0

# %% [markdown]
# #### Importando os dados

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
training = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# #### Remoção de registros com dados faltantes

# %%
training = training.dropna()

# %% [markdown]
# #### Convertendo os dados de cada imagem para uma matriz de inteiros e remodelando para uma matriz de dimsão 96x96

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %% [markdown]
# #### Convertendo os dados da imagem em array e atribuindo para variável X

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)

# %% [markdown]
# #### Cria um novo dataset chamado y, removendo a feature "Imagem"

# %%
y = training.drop(['Image'], axis=1)

# %% [markdown]
# #### Cria a variável y_ndarray convertendo a variável y para numpy.ndarray

# %%
y_ndarray = y.to_numpy()

# %% [markdown]
# #### Divide os dados do dataset em subconjuntos aleatórios de treino e teste

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_ndarray, test_size=0.3, random_state=42)

# %% [markdown]
# #### Criação da variável do tipo sequential
# https://keras.io/models/sequential/

# %%
model = Sequential()

# %% [markdown]
# #### Função para criar as camadas da rede neural convulacional
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Convolution2D: https://keras.io/layers/convolutional/#conv2d <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;LeakyReLU: https://keras.io/layers/advanced-activations/#leakyrelu <br/>
# BatchNormalization: https://keras.io/layers/normalization/#batchnormalization <br/>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;MaxPool2D: https://keras.io/layers/pooling/#maxpooling2d

# %%
def add_model(model, filters, maxpooling, *inputshape):   
    if inputshape:
        model.add(Convolution2D(filters, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
    else:
      if maxpooling:
        model.add(Convolution2D(filters, (3,3), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
        model.add(MaxPool2D(pool_size=(2, 2)))
      else:
        model.add(Convolution2D(filters, (3,3), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())

# %% [markdown]
# #### Cria a primeira camada com inut_shape

# %%
add_model(model, 32, False, True)

# %% [markdown]
# #### Cria as camadas ocultas

# %%
add_model(model, 32, True)
add_model(model, 64, False)
add_model(model, 64, True)
add_model(model, 128, False)
add_model(model, 128, True)
add_model(model, 256, False)
add_model(model, 256, True)
add_model(model, 512, False)
add_model(model, 512, True)

# %% [markdown]
# #### Cria as camadas ocultas

# %%
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))

# %% [markdown]
# #### Configura o modelo para treinamento

# %%
model.compile(optimizer='Adam', loss='mse', metrics=['mae', 'acc'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'layer10_epoc100_kernel3p3_drop0p1.hdf5', monitor='val_mae', verbose=1, save_best_only=False)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.02, callbacks=[checkpointer])
# Out:
# Train on 1468 samples, validate on 30 samples
# Epoch 1/100
# 1468/1468 [==============================] - 190s 130ms/step - loss: 155.3519 - mae: 7.5316 - acc: 0.4387 - val_loss: 168.8127 - val_mae: 10.8255 - val_acc: 0.7667
#
# Epoch 00001: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 2/100
# 1468/1468 [==============================] - 191s 130ms/step - loss: 25.1915 - mae: 3.9407 - acc: 0.5245 - val_loss: 12.6452 - val_mae: 2.7597 - val_acc: 0.7667
#
# Epoch 00002: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 3/100
# 1468/1468 [==============================] - 190s 129ms/step - loss: 22.3159 - mae: 3.7104 - acc: 0.5511 - val_loss: 33.9954 - val_mae: 5.0177 - val_acc: 0.7667
#
# Epoch 00003: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 4/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 18.6846 - mae: 3.4064 - acc: 0.5661 - val_loss: 16.1970 - val_mae: 3.4426 - val_acc: 0.8667
#
# Epoch 00004: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 5/100
# 1468/1468 [==============================] - 190s 129ms/step - loss: 17.7731 - mae: 3.2925 - acc: 0.5838 - val_loss: 48.2864 - val_mae: 6.2237 - val_acc: 0.9333
#
# Epoch 00005: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 6/100
# 1468/1468 [==============================] - 189s 129ms/step - loss: 15.0840 - mae: 3.0423 - acc: 0.6042 - val_loss: 44.1712 - val_mae: 5.8459 - val_acc: 0.7667
#
# Epoch 00006: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 7/100
# 1468/1468 [==============================] - 189s 129ms/step - loss: 15.0620 - mae: 3.0462 - acc: 0.6240 - val_loss: 44.4784 - val_mae: 5.9946 - val_acc: 0.7667
#
# Epoch 00007: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 8/100
# 1468/1468 [==============================] - 195s 133ms/step - loss: 11.8054 - mae: 2.6996 - acc: 0.6165 - val_loss: 18.4025 - val_mae: 3.7432 - val_acc: 0.5667
#
# Epoch 00008: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 9/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 12.3402 - mae: 2.7448 - acc: 0.6403 - val_loss: 7.7142 - val_mae: 2.2563 - val_acc: 0.7000
#
# Epoch 00009: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 10/100
# 1468/1468 [==============================] - 187s 128ms/step - loss: 12.5737 - mae: 2.7729 - acc: 0.6546 - val_loss: 36.2208 - val_mae: 5.3781 - val_acc: 0.9000
#
# Epoch 00010: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 11/100
# 1468/1468 [==============================] - 189s 129ms/step - loss: 13.2201 - mae: 2.8524 - acc: 0.6621 - val_loss: 34.8913 - val_mae: 5.3919 - val_acc: 0.9333
#
# Epoch 00011: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 12/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 11.3470 - mae: 2.6253 - acc: 0.6826 - val_loss: 6.7252 - val_mae: 2.1009 - val_acc: 0.9000
#
# Epoch 00012: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 13/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 9.9992 - mae: 2.4588 - acc: 0.6478 - val_loss: 15.0981 - val_mae: 3.2783 - val_acc: 0.8333
#
# Epoch 00013: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch
100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 3.9179 - mae: 1.5032 - acc: 0.8399 - val_loss: 8.4419 - val_mae: 2.5090 - val_acc: 0.8000
#
# Epoch 00095: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 96/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 3.9036 - mae: 1.5190 - acc: 0.8365 - val_loss: 3.1841 - val_mae: 1.3942 - val_acc: 0.7667
#
# Epoch 00096: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 97/100
# 1468/1468 [==============================] - 190s 129ms/step - loss: 3.9329 - mae: 1.5254 - acc: 0.8474 - val_loss: 2.6787 - val_mae: 1.1981 - val_acc: 0.8000
#
# Epoch 00097: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 98/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 3.9798 - mae: 1.5272 - acc: 0.8460 - val_loss: 2.8353 - val_mae: 1.2756 - val_acc: 0.8000
#
# Epoch 00098: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 99/100
# 1468/1468 [==============================] - 188s 128ms/step - loss: 6.3951 - mae: 1.9690 - acc: 0.8379 - val_loss: 2.2101 - val_mae: 1.1177 - val_acc: 0.8000
#
# Epoch 00099: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5
# Epoch 100/100
# 1468/1468 [==============================] - 189s 128ms/step - loss: 3.9891 - mae: 1.5297 - acc: 0.8331 - val_loss: 7.3017 - val_mae: 2.3215 - val_acc: 0.8000
#
# Epoch 00100: saving model to layer10_epoc100_kernel3p3_drop0p1.hdf5

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 8.578890464758947
# Test accuracy: 2.4845972061157227

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 4.297087849114914
# Test accuracy: 1.6626379489898682

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
train_predicts = model.predict(X_train)

# %%
plt.imshow(X_train[0].reshape((96,96)), cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[0][i-1], train_predicts[0][i], 'ro')
    plt.plot(y_train[0][i-1], y_train[0][i], 'x', color='green')

plt.show()

# %% [markdown]
# #### Loss vs Epoch

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'], linewidth=2, label="train")
plt.plot(history.history['val_loss'], linewidth=2, label="val ")
plt.legend()
plt.title('Loss vs Epoch')
plt.grid()

plt.xlabel("Epoch")
plt.ylabel("Log Loss")
fig= plt.figure(figsize=(20,15))
plt.show()

# %% [markdown]
# #### Mean Absolute Error vs Epoch

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['mae'], linewidth=2)
plt.plot(history.history['val_mae'], linewidth=2)
plt.title('Mean Absolute Error vs Epoch')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %% [markdown]
# #### Accuracy vs Epoch

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['acc'], linewidth=2)
plt.plot(history.history['val_acc'], linewidth=2)
plt.title('Accuracy vs Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
predict = model.predict(test_X)

# %%
header = list(y.columns)

# %%
df_predict = pd.DataFrame(predict, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = df_predict.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
SampleSubmission.to_csv('submission_100_epochs_kernel3x3_2.csv', index=False)

# %%
pd.DataFrame(history.history.items()).to_csv('history_submission_100_epochs_kernel3x3.csv', index=False)
