# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
import random

import sys
import matplotlib
import sklearn
import numpy
import keras
import tensorflow as tf 
from keras.layers import Dense, Flatten, BatchNormalization, Dropout, Convolution2D, MaxPool2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import Callback
# Out:
# Using TensorFlow backend.

# %%
print('Versão Python ', sys.version)
print('Versão Numpy ', numpy.version.version)
print('Versão Pandas ', pd.__version__)
print('Versão Matplotlib ', matplotlib.__version__)
print('Versão Sklearn ', sklearn.__version__)
print('Versão Keras', keras.__version__)
print('Versão TensorFlow', tf.__version__)
# Out:
# Versão Python  3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:18:16) [MSC v.1916 64 bit (AMD64)]
# Versão Numpy  1.17.4
# Versão Pandas  0.25.3
# Versão Matplotlib  3.1.2
# Versão Sklearn  0.22.1
# Versão Keras 2.3.1
# Versão TensorFlow 2.0.0

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
training = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %%
training = training.dropna()

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)

# %%
y = training.drop(['Image'], axis=1)

# %%
y_ndarray = y.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_ndarray, test_size=0.3, random_state=42)

# %%
model = Sequential()

# %%
def add_model(model, filters, maxpooling, *inputshape):   
    if inputshape:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False, input_shape=(96,96,1)))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
    else:
      if maxpooling:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
        model.add(Dropout(0.2))
        model.add(MaxPool2D(pool_size=(2, 2)))
      else:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(Dropout(0.2))
        model.add(BatchNormalization())

# %%
add_model(model, 32, False, True)

# %%
add_model(model, 32, True)
add_model(model, 64, False)
add_model(model, 64, True)
add_model(model, 128, False)
add_model(model, 128, True)
add_model(model, 256, False)
add_model(model, 256, True)
add_model(model, 512, False)
add_model(model, 512, True)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))

# %%
model.compile(optimizer='Adam', loss='mse', metrics=['mae', 'acc'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'layer10_epoc100_kernel5p5_fext_dropout=0p2.hdf5', monitor='val_mae', verbose=1, save_best_only=False)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.02, callbacks=[checkpointer])
# Out:
# Train on 1468 samples, validate on 30 samples
# Epoch 1/100
# 1468/1468 [==============================] - 219s 149ms/step - loss: 149.3786 - mae: 7.5052 - acc: 0.4203 - val_loss: 55.3981 - val_mae: 6.3291 - val_acc: 0.7667
#
# Epoch 00001: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 2/100
# 1468/1468 [==============================] - 204s 139ms/step - loss: 26.3721 - mae: 4.0561 - acc: 0.5061 - val_loss: 19.3516 - val_mae: 3.6443 - val_acc: 0.8000
#
# Epoch 00002: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 3/100
# 1468/1468 [==============================] - 197s 134ms/step - loss: 21.4413 - mae: 3.6459 - acc: 0.5722 - val_loss: 6.1357 - val_mae: 1.8871 - val_acc: 0.7667
#
# Epoch 00003: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 4/100
# 1468/1468 [==============================] - 185s 126ms/step - loss: 17.7355 - mae: 3.3148 - acc: 0.5954 - val_loss: 23.9174 - val_mae: 4.3164 - val_acc: 0.7667
#
# Epoch 00004: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 5/100
# 1468/1468 [==============================] - 184s 125ms/step - loss: 17.2497 - mae: 3.2661 - acc: 0.6056 - val_loss: 36.1176 - val_mae: 5.2118 - val_acc: 0.5333
#
# Epoch 00005: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 6/100
# 1468/1468 [==============================] - 202s 137ms/step - loss: 14.4500 - mae: 2.9880 - acc: 0.6185 - val_loss: 7.6417 - val_mae: 2.2757 - val_acc: 0.8333
#
# Epoch 00006: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 7/100
# 1468/1468 [==============================] - 196s 134ms/step - loss: 13.0680 - mae: 2.8400 - acc: 0.6424 - val_loss: 3.4023 - val_mae: 1.3539 - val_acc: 0.9000
#
# Epoch 00007: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 8/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 12.4360 - mae: 2.7655 - acc: 0.6526 - val_loss: 29.2676 - val_mae: 4.7414 - val_acc: 0.9000
#
# Epoch 00008: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 9/100
# 1468/1468 [==============================] - 203s 138ms/step - loss: 11.9605 - mae: 2.7128 - acc: 0.6683 - val_loss: 15.6477 - val_mae: 3.4503 - val_acc: 0.7333
#
# Epoch 00009: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 10/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 15.2449 - mae: 3.0707 - acc: 0.6785 - val_loss: 3.2995 - val_mae: 1.3470 - val_acc: 0.8667
#
# Epoch 00010: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 11/100
# 1468/1468 [==============================] - 210s 143ms/step - loss: 12.3450 - mae: 2.7505 - acc: 0.6730 - val_loss: 19.5398 - val_mae: 3.9355 - val_acc: 0.8333
#
# Epoch 00011: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 12/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 9.7716 - mae: 2.4508 - acc: 0.6873 - val_loss: 3.4305 - val_mae: 1.3816 - val_acc: 0.9000
#
# Epoch 00012: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 13/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 9.5855 - mae: 2.4260 - acc: 0.6975 - val_loss: 3.0196 - val_mae: 1.2362 - val_acc: 0.8667
#
# Epoch 00013: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 14/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 9.0621 - mae: 2.3569 - acc: 0.6935 - val_loss: 7.0037 - val_mae: 2.2156 - val_acc: 0.9000
#
# Epoch 00014: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 15/100
# 1468/1468 [==============================] - 204s 139ms/step - loss: 8.8880 - mae: 2.3258 - acc: 0.6955 - val_loss: 9.6054 - val_mae: 2.7205 - val_acc: 0.8333
#
# Epoch 00015: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 16/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 8.9655 - mae: 2.3360 - acc: 0.7275 - val_loss: 9.0560 - val_mae: 2.4934 - val_acc: 0.8000
#
# Epoch 00016: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 17/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 8.9564 - mae: 2.3354 - acc: 0.7153 - val_loss: 7.7366 - val_mae: 2.3670 - val_acc: 0.8333
#
# Epoch 00017: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 18/100
# 1468/1468 [==============================] - 202s 137ms/step - loss: 9.7705 - mae: 2.4353 - acc: 0.7214 - val_loss: 10.4439 - val_mae: 2.7867 - val_acc: 0.8667
#
# Epoch 00018: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 19/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 8.1141 - mae: 2.2237 - acc: 0.7337 - val_loss: 3.2462 - val_mae: 1.4179 - val_acc: 0.7667
#
# Epoch 00019: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 20/100
# 1468/1468 [==============================] - 212s 145ms/step - loss: 8.2466 - mae: 2.2305 - acc: 0.7377 - val_loss: 9.5347 - val_mae: 2.5629 - val_acc: 0.8000
#
# Epoch 00020: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 21/100
# 1468/1468 [==============================] - 212s 144ms/step - loss: 10.2457 - mae: 2.4959 - acc: 0.7418 - val_loss: 10.5068 - val_mae: 2.7970 - val_acc: 0.8333
#
# Epoch 00021: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 22/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 7.2041 - mae: 2.0948 - acc: 0.7507 - val_loss: 3.0895 - val_mae: 1.2528 - val_acc: 0.7667
#
# Epoch 00022: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 23/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 7.3899 - mae: 2.1085 - acc: 0.7384 - val_loss: 3.4829 - val_mae: 1.3313 - val_acc: 0.7667
#
# Epoch 00023: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 24/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 6.7404 - mae: 2.0170 - acc: 0.7514 - val_loss: 4.4019 - val_mae: 1.6233 - val_acc: 0.8667
#
# Epoch 00024: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 25/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 6.8933 - mae: 2.0379 - acc: 0.7554 - val_loss: 9.6485 - val_mae: 2.7357 - val_acc: 0.8333
#
# Epoch 00025: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 26/100
# 1468/1468 [==============================] - 197s 134ms/step - loss: 7.8697 - mae: 2.1770 - acc: 0.7575 - val_loss: 11.0937 - val_mae: 2.9446 - val_acc: 0.8333
#
# Epoch 00026: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 27/100
# 1468/1468 [==============================] - 205s 140ms/step - loss: 10.6198 - mae: 2.5259 - acc: 0.7589 - val_loss: 4.5722 - val_mae: 1.5901 - val_acc: 0.7667
#
# Epoch 00027: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 28/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 8.0388 - mae: 2.2054 - acc: 0.7452 - val_loss: 3.4707 - val_mae: 1.4035 - val_acc: 0.9000
#
# Epoch 00028: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 29/100
# 1468/1468 [==============================] - 212s 144ms/step - loss: 6.2450 - mae: 1.9279 - acc: 0.7623 - val_loss: 3.5240 - val_mae: 1.4724 - val_acc: 0.8667
#
# Epoch 00029: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 30/100
# 1468/1468 [==============================] - 203s 138ms/step - loss: 5.9811 - mae: 1.8854 - acc: 0.7527 - val_loss: 4.3908 - val_mae: 1.6694 - val_acc: 0.9000
#
# Epoch 00030: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 31/100
# 1468/1468 [==============================] - 204s 139ms/step - loss: 7.6384 - mae: 2.1367 - acc: 0.7759 - val_loss: 15.4061 - val_mae: 3.4991 - val_acc: 0.8333
#
# Epoch 00031: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 32/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 5.9075 - mae: 1.8836 - acc: 0.7725 - val_loss: 14.2532 - val_mae: 3.3519 - val_acc: 0.8667
#
# Epoch 00032: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 33/100
# 1468/1468 [==============================] - 202s 138ms/step - loss: 7.1936 - mae: 2.0708 - acc: 0.7786 - val_loss: 7.4583 - val_mae: 2.3054 - val_acc: 0.9000
#
# Epoch 00033: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 34/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 5.5309 - mae: 1.8155 - acc: 0.7732 - val_loss: 3.7552 - val_mae: 1.4507 - val_acc: 0.8000
#
# Epoch 00034: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 35/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 5.7747 - mae: 1.8508 - acc: 0.7875 - val_loss: 5.9668 - val_mae: 1.9965 - val_acc: 0.9000
#
# Epoch 00035: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 36/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 5.7087 - mae: 1.8437 - acc: 0.7752 - val_loss: 3.7391 - val_mae: 1.4875 - val_acc: 0.7333
#
# Epoch 00036: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 37/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 5.0599 - mae: 1.7300 - acc: 0.7807 - val_loss: 3.4849 - val_mae: 1.4633 - val_acc: 0.7333
#
# Epoch 00037: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 38/100
# 1468/1468 [==============================] - 213s 145ms/step - loss: 5.9247 - mae: 1.8702 - acc: 0.7793 - val_loss: 2.7890 - val_mae: 1.1774 - val_acc: 0.8333
#
# Epoch 00038: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 39/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 5.9389 - mae: 1.8670 - acc: 0.7732 - val_loss: 2.7604 - val_mae: 1.2236 - val_acc: 0.9333
#
# Epoch 00039: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 40/100
# 1468/1468 [==============================] - 197s 135ms/step - loss: 5.6217 - mae: 1.8161 - acc: 0.8018 - val_loss: 2.7369 - val_mae: 1.1341 - val_acc: 0.8333
#
# Epoch 00040: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 41/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 6.5684 - mae: 1.9642 - acc: 0.7943 - val_loss: 4.1341 - val_mae: 1.5423 - val_acc: 0.8000
#
# Epoch 00041: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 42/100
# 1468/1468 [==============================] - 206s 140ms/step - loss: 6.6772 - mae: 1.9791 - acc: 0.7902 - val_loss: 7.8491 - val_mae: 2.3943 - val_acc: 0.8333
#
# Epoch 00042: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 43/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 5.7947 - mae: 1.8513 - acc: 0.7820 - val_loss: 2.9258 - val_mae: 1.2780 - val_acc: 0.8667
#
# Epoch 00043: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 44/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 5.5846 - mae: 1.8128 - acc: 0.7997 - val_loss: 4.0133 - val_mae: 1.6112 - val_acc: 0.8667
#
# Epoch 00044: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 45/100
# 1468/1468 [==============================] - 203s 138ms/step - loss: 5.4221 - mae: 1.7968 - acc: 0.7834 - val_loss: 6.3961 - val_mae: 2.0972 - val_acc: 0.7667
#
# Epoch 00045: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 46/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 5.0258 - mae: 1.7222 - acc: 0.7990 - val_loss: 5.3165 - val_mae: 1.9345 - val_acc: 0.9000
#
# Epoch 00046: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 47/100
# 1468/1468 [==============================] - 213s 145ms/step - loss: 5.7498 - mae: 1.8427 - acc: 0.8127 - val_loss: 2.9115 - val_mae: 1.1598 - val_acc: 0.8000
#
# Epoch 00047: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 48/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 4.8952 - mae: 1.7014 - acc: 0.8065 - val_loss: 2.7586 - val_mae: 1.2351 - val_acc: 0.8333
#
# Epoch 00048: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 49/100
# 1468/1468 [==============================] - 197s 134ms/step - loss: 6.3539 - mae: 1.9440 - acc: 0.7997 - val_loss: 3.3704 - val_mae: 1.3305 - val_acc: 0.8667
#
# Epoch 00049: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 50/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 4.6241 - mae: 1.6509 - acc: 0.7888 - val_loss: 4.3031 - val_mae: 1.6719 - val_acc: 0.7667
#
# Epoch 00050: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 51/100
# 1468/1468 [==============================] - 204s 139ms/step - loss: 4.8379 - mae: 1.6902 - acc: 0.8106 - val_loss: 9.9295 - val_mae: 2.7814 - val_acc: 0.9000
#
# Epoch 00051: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 52/100
# 1468/1468 [==============================] - 200s 137ms/step - loss: 5.5623 - mae: 1.8168 - acc: 0.8004 - val_loss: 2.8897 - val_mae: 1.2592 - val_acc: 0.8333
#
# Epoch 00052: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 53/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 5.5755 - mae: 1.8018 - acc: 0.8065 - val_loss: 7.2441 - val_mae: 2.3023 - val_acc: 0.7000
#
# Epoch 00053: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 54/100
# 1468/1468 [==============================] - 203s 139ms/step - loss: 4.6063 - mae: 1.6563 - acc: 0.8045 - val_loss: 4.9246 - val_mae: 1.8283 - val_acc: 0.7667
#
# Epoch 00054: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 55/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 4.5848 - mae: 1.6379 - acc: 0.8065 - val_loss: 4.1684 - val_mae: 1.6678 - val_acc: 0.8000
#
# Epoch 00055: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 56/100
# 1468/1468 [==============================] - 225s 153ms/step - loss: 5.0765 - mae: 1.7112 - acc: 0.8086 - val_loss: 4.7070 - val_mae: 1.7342 - val_acc: 0.8000
#
# Epoch 00056: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 57/100
# 1468/1468 [==============================] - 202s 138ms/step - loss: 4.3468 - mae: 1.5989 - acc: 0.8256 - val_loss: 2.0033 - val_mae: 0.9886 - val_acc: 0.9000
#
# Epoch 00057: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 58/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 4.6604 - mae: 1.6426 - acc: 0.8195 - val_loss: 7.9044 - val_mae: 2.3891 - val_acc: 0.8333
#
# Epoch 00058: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 59/100
# 1468/1468 [==============================] - 207s 141ms/step - loss: 4.3748 - mae: 1.6067 - acc: 0.8106 - val_loss: 3.5979 - val_mae: 1.3753 - val_acc: 0.8000
#
# Epoch 00059: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 60/100
# 1468/1468 [==============================] - 199s 136ms/step - loss: 4.3963 - mae: 1.6073 - acc: 0.8072 - val_loss: 5.0988 - val_mae: 1.8596 - val_acc: 0.7000
#
# Epoch 00060: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 61/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 4.0899 - mae: 1.5472 - acc: 0.8134 - val_loss: 2.2828 - val_mae: 1.0628 - val_acc: 0.7333
#
# Epoch 00061: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 62/100
# 1468/1468 [==============================] - 203s 138ms/step - loss: 4.8031 - mae: 1.6824 - acc: 0.8147 - val_loss: 6.9750 - val_mae: 2.2246 - val_acc: 0.9000
#
# Epoch 00062: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 63/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.2287 - mae: 1.5773 - acc: 0.8297 - val_loss: 2.6248 - val_mae: 1.1116 - val_acc: 0.7000
#
# Epoch 00063: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 64/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 4.0822 - mae: 1.5535 - acc: 0.8127 - val_loss: 2.6855 - val_mae: 1.1117 - val_acc: 0.8000
#
# Epoch 00064: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 65/100
# 1468/1468 [==============================] - 213s 145ms/step - loss: 5.5820 - mae: 1.8218 - acc: 0.8188 - val_loss: 3.1820 - val_mae: 1.3704 - val_acc: 0.7667
#
# Epoch 00065: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 66/100
# 1468/1468 [==============================] - 202s 138ms/step - loss: 4.9277 - mae: 1.7034 - acc: 0.8263 - val_loss: 9.5406 - val_mae: 2.7523 - val_acc: 0.7667
#
# Epoch 00066: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 67/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 5.2398 - mae: 1.7573 - acc: 0.8086 - val_loss: 3.5714 - val_mae: 1.4110 - val_acc: 0.8333
#
# Epoch 00067: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 68/100
# 1468/1468 [==============================] - 202s 138ms/step - loss: 5.0096 - mae: 1.7308 - acc: 0.8188 - val_loss: 5.3578 - val_mae: 1.9534 - val_acc: 0.8000
#
# Epoch 00068: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 69/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 4.3289 - mae: 1.6028 - acc: 0.8297 - val_loss: 6.8187 - val_mae: 2.2173 - val_acc: 0.8667
#
# Epoch 00069: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 70/100
# 1468/1468 [==============================] - 197s 134ms/step - loss: 4.7634 - mae: 1.6813 - acc: 0.8256 - val_loss: 8.8511 - val_mae: 2.5910 - val_acc: 0.8000
#
# Epoch 00070: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 71/100
# 1468/1468 [==============================] - 203s 138ms/step - loss: 4.3343 - mae: 1.5918 - acc: 0.8208 - val_loss: 2.2918 - val_mae: 1.0520 - val_acc: 0.7667
#
# Epoch 00071: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 72/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 3.9979 - mae: 1.5370 - acc: 0.8263 - val_loss: 2.8126 - val_mae: 1.2402 - val_acc: 0.8333
#
# Epoch 00072: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 73/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 5.5471 - mae: 1.8028 - acc: 0.8249 - val_loss: 2.9821 - val_mae: 1.2878 - val_acc: 0.7000
#
# Epoch 00073: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 74/100
# 1468/1468 [==============================] - 221s 150ms/step - loss: 4.2040 - mae: 1.5767 - acc: 0.8236 - val_loss: 5.7214 - val_mae: 1.9542 - val_acc: 0.8000
#
# Epoch 00074: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 75/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.5476 - mae: 1.6359 - acc: 0.8147 - val_loss: 4.1575 - val_mae: 1.6452 - val_acc: 0.8000
#
# Epoch 00075: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 76/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.1304 - mae: 1.5594 - acc: 0.8236 - val_loss: 3.0398 - val_mae: 1.3408 - val_acc: 0.7333
#
# Epoch 00076: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 77/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 3.7154 - mae: 1.4751 - acc: 0.8304 - val_loss: 2.5983 - val_mae: 1.1152 - val_acc: 0.8000
#
# Epoch 00077: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 78/100
# 1468/1468 [==============================] - 197s 134ms/step - loss: 4.6068 - mae: 1.6429 - acc: 0.8379 - val_loss: 3.4032 - val_mae: 1.3324 - val_acc: 0.8333
#
# Epoch 00078: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 79/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.7139 - mae: 1.6804 - acc: 0.8277 - val_loss: 9.0308 - val_mae: 2.6497 - val_acc: 0.8333
#
# Epoch 00079: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 80/100
# 1468/1468 [==============================] - 203s 138ms/step - loss: 4.4063 - mae: 1.6130 - acc: 0.8202 - val_loss: 7.1543 - val_mae: 2.2586 - val_acc: 0.8667
#
# Epoch 00080: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 81/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.8471 - mae: 1.6950 - acc: 0.8263 - val_loss: 3.4431 - val_mae: 1.4410 - val_acc: 0.8667
#
# Epoch 00081: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 82/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 3.7974 - mae: 1.4933 - acc: 0.8331 - val_loss: 2.1992 - val_mae: 1.0293 - val_acc: 0.8333
#
# Epoch 00082: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 83/100
# 1468/1468 [==============================] - 210s 143ms/step - loss: 4.1785 - mae: 1.5728 - acc: 0.8426 - val_loss: 2.6669 - val_mae: 1.1812 - val_acc: 0.8000
#
# Epoch 00083: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 84/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.0634 - mae: 1.5586 - acc: 0.8372 - val_loss: 3.6726 - val_mae: 1.5068 - val_acc: 0.8000
#
# Epoch 00084: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 85/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.2498 - mae: 1.5753 - acc: 0.8229 - val_loss: 2.8293 - val_mae: 1.1735 - val_acc: 0.8667
#
# Epoch 00085: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 86/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 4.3591 - mae: 1.6057 - acc: 0.8317 - val_loss: 6.3541 - val_mae: 2.1318 - val_acc: 0.8333
#
# Epoch 00086: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 87/100
# 1468/1468 [==============================] - 199s 135ms/step - loss: 4.0218 - mae: 1.5436 - acc: 0.8331 - val_loss: 3.2015 - val_mae: 1.4252 - val_acc: 0.8333
#
# Epoch 00087: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 88/100
# 1468/1468 [==============================] - 201s 137ms/step - loss: 3.7770 - mae: 1.4959 - acc: 0.8406 - val_loss: 8.5116 - val_mae: 2.5487 - val_acc: 0.8333
#
# Epoch 00088: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 89/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 4.1084 - mae: 1.5647 - acc: 0.8202 - val_loss: 3.0855 - val_mae: 1.2952 - val_acc: 0.7667
#
# Epoch 00089: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 90/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 3.8410 - mae: 1.5056 - acc: 0.8338 - val_loss: 7.1384 - val_mae: 2.3287 - val_acc: 0.8667
#
# Epoch 00090: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 91/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 4.1622 - mae: 1.5733 - acc: 0.8440 - val_loss: 4.8828 - val_mae: 1.7806 - val_acc: 0.8000
#
# Epoch 00091: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 92/100
# 1468/1468 [==============================] - 216s 147ms/step - loss: 3.7894 - mae: 1.4960 - acc: 0.8508 - val_loss: 3.2456 - val_mae: 1.3675 - val_acc: 0.8000
#
# Epoch 00092: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 93/100
# 1468/1468 [==============================] - 197s 134ms/step - loss: 3.7075 - mae: 1.4831 - acc: 0.8413 - val_loss: 2.9058 - val_mae: 1.2695 - val_acc: 0.8333
#
# Epoch 00093: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 94/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.1540 - mae: 1.5658 - acc: 0.8277 - val_loss: 2.9892 - val_mae: 1.2789 - val_acc: 0.8333
#
# Epoch 00094: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 95/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 3.8907 - mae: 1.5151 - acc: 0.8454 - val_loss: 10.2320 - val_mae: 2.8017 - val_acc: 0.7667
#
# Epoch 00095: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 96/100
# 1468/1468 [==============================] - 196s 134ms/step - loss: 5.2009 - mae: 1.7516 - acc: 0.8426 - val_loss: 7.6548 - val_mae: 2.4044 - val_acc: 0.7667
#
# Epoch 00096: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 97/100
# 1468/1468 [==============================] - 196s 134ms/step - loss: 4.7961 - mae: 1.6984 - acc: 0.8358 - val_loss: 6.1306 - val_mae: 2.0327 - val_acc: 0.9000
#
# Epoch 00097: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 98/100
# 1468/1468 [==============================] - 205s 140ms/step - loss: 4.2544 - mae: 1.5919 - acc: 0.8324 - val_loss: 3.4904 - val_mae: 1.4628 - val_acc: 0.8000
#
# Epoch 00098: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 99/100
# 1468/1468 [==============================] - 198s 135ms/step - loss: 4.1604 - mae: 1.5745 - acc: 0.8413 - val_loss: 3.5728 - val_mae: 1.4646 - val_acc: 0.8000
#
# Epoch 00099: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 100/100
# 1468/1468 [==============================] - 200s 136ms/step - loss: 3.6534 - mae: 1.4658 - acc: 0.8447 - val_loss: 2.5189 - val_mae: 1.1272 - val_acc: 0.8333
#
# Epoch 00100: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.2858125175642448
# Test accuracy: 1.0961841344833374

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
train_predicts = model.predict(X_train)

# %%
plt.imshow(X_train[0].reshape((96,96)), cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[0][i-1], train_predicts[0][i], 'ro')
    plt.plot(y_train[0][i-1], y_train[0][i], 'x', color='green')

plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'], linewidth=2, label="train")
plt.plot(history.history['val_loss'], linewidth=2, label="val ")
plt.legend()
plt.title('Loss vs Epoch')
plt.grid()

plt.xlabel("Epoch")
plt.ylabel("Log Loss")
fig= plt.figure(figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['mae'], linewidth=2)
plt.plot(history.history['val_mae'], linewidth=2)
plt.title('Mean Absolute Error vs Epoch')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['acc'], linewidth=2)
plt.plot(history.history['val_acc'], linewidth=2)
plt.title('Accuracy vs Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
predict = model.predict(test_X)

# %%
header = list(y.columns)

# %%
df_predict = pd.DataFrame(predict, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = df_predict.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
SampleSubmission.to_csv('submission_100_epochs_kernel5x5_fext_dropout=0p2.csv', index=False)

# %%
pd.DataFrame(history.history.items()).to_csv('history_submission_100_epochs_kernel5x5_fext_dropout=0p2.csv', index=False)
