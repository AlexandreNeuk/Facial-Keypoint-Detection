# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from sklearn.model_selection import train_test_split 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, AvgPool2D, BatchNormalization, Dropout, Activation, MaxPooling2D
from keras.optimizers import Adam
from keras import regularizers
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from keras.layers import Activation, Convolution2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout, Conv2D,MaxPool2D, ZeroPadding2D

# %%
x = np.random.random_integers(1, 100, 5)
plt.hist(x, bins=20)
plt.ylabel('No of times')
plt.show()
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning: This function is deprecated. Please call randint(1, 100 + 1) instead
#   """Entry point for launching an IPython kernel.

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
test = pd.read_csv('test.csv')
training = pd.read_csv('training.csv')

# %%
plt.hist(training, bins=20)
plt.ylabel('No of times')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-8f66e8f6f895> in <module>
# ----> 1 plt.hist(training, bins=20)
#       2 plt.ylabel('No of times')
#       3 plt.show()
#
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, data, **kwargs)
#    2634         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2635         color=color, label=label, stacked=stacked, normed=normed,
# -> 2636         **({"data": data} if data is not None else {}), **kwargs)
#    2637
#    2638
#
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
#    1598         if data is None:
# -> 1599             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1600
#    1601         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\matplotlib\axes\_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, **kwargs)
#    6741                     # python's min/max ignore nan,
#    6742                     # np.minnan returns nan for all nan input
# -> 6743                     xmin = min(xmin, np.nanmin(xi))
#    6744                     xmax = max(xmax, np.nanmax(xi))
#    6745             # make sure we have seen at least one non-nan and finite
#
# <__array_function__ internals> in nanmin(*args, **kwargs)
#
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\numpy\lib\nanfunctions.py in nanmin(a, axis, out, keepdims)
#     325         # Slow, but safe for subclasses of ndarray
#     326         a, mask = _replace_nan(a, +np.inf)
# --> 327         res = np.amin(a, axis=axis, out=out, **kwargs)
#     328         if mask is None:
#     329             return res
#
# <__array_function__ internals> in amin(*args, **kwargs)
#
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py in amin(a, axis, out, keepdims, initial, where)
#    2744     """
#    2745     return _wrapreduction(a, np.minimum, 'min', axis, None, out,
# -> 2746                           keepdims=keepdims, initial=initial, where=where)
#    2747
#    2748
#
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\numpy\core\fromnumeric.py in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      88                 return reduction(axis=axis, out=out, **passkwargs)
#      89
# ---> 90     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      91
#      92
#
# TypeError: '<=' not supported between instances of 'float' and 'str'

# %%
training = training.dropna()

# %%
training.shape, type(training)
# Out:
# ((2140, 31), pandas.core.frame.DataFrame)

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
def get_image_and_dots(df, index):
    image = plt.imshow(df['Image'][index],cmap='gray')
    l = []
    for i in range(1,31,2):
        l.append(plt.plot(df.loc[index][i-1], df.loc[index][i], 'ro'))
        
    return image, l

# %%
fig = plt.figure(figsize=(8, 8))
fig.subplots_adjust(
    left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    get_image_and_dots(training, i)

plt.show()

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)
y = training.drop(['Image'], axis=1)

# %%
X.shape
# Out:
# (2140, 96, 96, 1)

# %%
y.shape
# Out:
# (2140, 30)

# %%
type(X), type(y)
# Out:
# (numpy.ndarray, pandas.core.frame.DataFrame)

# %%
y2 = y.to_numpy()

# %%
type(y2), y2.shape
# Out:
# (numpy.ndarray, (2140, 30))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size=0.3, random_state=42)

# %%
model = Sequential()

# %%
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# %%
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
# model.add(BatchNormalization())
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

# %%
model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 96, 96, 32)        288
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 96, 96, 32)        128
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 96, 96, 32)        9216
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 96, 96, 32)        128
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 48, 48, 64)        18432
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 48, 48, 64)        36864
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 24, 24, 96)        55296
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 24, 24, 96)        384
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 24, 24, 96)        82944
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 24, 24, 96)        384
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 96)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 12, 12, 128)       110592
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 12, 12, 128)       147456
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 6, 6, 256)         294912
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 6, 6, 256)         589824
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 3, 3, 512)         1179648
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 3, 3, 512)         2359296
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 4608)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               2359808
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 7,268,670
# Trainable params: 7,264,318
# Non-trainable params: 4,352
# _________________________________________________________________

# %%
model.compile(optimizer='Adam', 
              loss='mse', 
              metrics=['mae'])

# %%
model.fit(X_train, y_train, epochs=50)
# Out:
# Epoch 1/50
# 1498/1498 [==============================] - 180s 120ms/step - loss: 194.0698 - mae: 8.4926
# Epoch 2/50
# 1498/1498 [==============================] - 180s 120ms/step - loss: 25.7682 - mae: 4.0001
# Epoch 3/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 21.5636 - mae: 3.6519
# Epoch 4/50
# 1498/1498 [==============================] - 180s 120ms/step - loss: 18.3477 - mae: 3.3631
# Epoch 5/50
# 1498/1498 [==============================] - 182s 122ms/step - loss: 16.8899 - mae: 3.2173
# Epoch 6/50
# Epoch 34/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 6.2272 - mae: 1.9386
# Epoch 35/50
# 1498/1498 [==============================] - 182s 121ms/step - loss: 5.6462 - mae: 1.8393
# Epoch 36/50
# 1498/1498 [==============================] - 184s 123ms/step - loss: 6.0976 - mae: 1.9127
# Epoch 37/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 6.0188 - mae: 1.8915
# Epoch 38/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 5.6517 - mae: 1.8375
# Epoch 39/50
# 1498/1498 [==============================] - 194s 129ms/step - loss: 6.6148 - mae: 1.9922
# Epoch 40/50
# 1498/1498 [==============================] - 179s 120ms/step - loss: 5.6459 - mae: 1.8406
# Epoch 41/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 5.4582 - mae: 1.8109
# Epoch 42/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 4.9925 - mae: 1.7244
# Epoch 43/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 5.3462 - mae: 1.7860
# Epoch 44/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 6.4224 - mae: 1.9733
# Epoch 45/50
# 1498/1498 [==============================] - 179s 120ms/step - loss: 5.1162 - mae: 1.7389
# Epoch 46/50
# 1498/1498 [==============================] - 182s 122ms/step - loss: 7.5696 - mae: 2.1334
# Epoch 47/50
# 1498/1498 [==============================] - 181s 121ms/step - loss: 5.3265 - mae: 1.7886
# Epoch 48/50
# 1498/1498 [==============================] - 180s 120ms/step - loss: 5.2628 - mae: 1.7601
# Epoch 49/50
# 1498/1498 [==============================] - 189s 126ms/step - loss: 5.1498 - mae: 1.7528
# Epoch 50/50
# 1498/1498 [==============================] - 180s 120ms/step - loss: 5.2863 - mae: 1.7772

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.7121073174699446
# Test accuracy: 1.2041782140731812

# %%
model.save('keypoint_model22.h5')

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
test.shape, type(test)
# Out:
# ((1783, 2), pandas.core.frame.DataFrame)

# %%
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
test_res = model.predict(test_X)

# %%
train_predicts = model.predict(X_train)

# %%
n = 11

xv = X_train[n].reshape((96,96))
plt.imshow(xv,cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[n][i-1], train_predicts[n][i], 'ro')
    plt.plot(y_train[n][i-1], y_train[n][i], 'x', color='green')

plt.show()

# %%
header = list(y.columns)

# %%
test_predicts = pd.DataFrame(test_res, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = test_predicts.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]
# Out:
# c:\users\alexandre\miniconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
my_submission = SampleSubmission

# %%
my_submission.to_csv('submission_50_epocas.csv', index=False)
