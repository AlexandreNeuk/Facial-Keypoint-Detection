# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split 
import matplotlib.patches as mpatches
from matplotlib import pyplot as plt
import random

import sys
import matplotlib
import sklearn
import numpy
import keras
import tensorflow as tf 
from keras.layers import Dense, Flatten, BatchNormalization, Dropout, Convolution2D, MaxPool2D
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam
from keras.callbacks import Callback

# %%
print('Versão Python ', sys.version)
print('Versão Numpy ', numpy.version.version)
print('Versão Pandas ', pd.__version__)
print('Versão Matplotlib ', matplotlib.__version__)
print('Versão Sklearn ', sklearn.__version__)
print('Versão Keras', keras.__version__)
print('Versão TensorFlow', tf.__version__)
# Out:
# Versão Python  3.6.10 |Anaconda, Inc.| (default, Jan  7 2020, 15:18:16) [MSC v.1916 64 bit (AMD64)]
# Versão Numpy  1.17.4
# Versão Pandas  0.25.3
# Versão Matplotlib  3.1.2
# Versão Sklearn  0.22.1
# Versão Keras 2.3.1
# Versão TensorFlow 2.0.0

# %%
IdLookupTable = pd.read_csv('IdLookupTable.csv')
SampleSubmission = pd.read_csv('SampleSubmission.csv')
training = pd.read_csv('training.csv')
test = pd.read_csv('test.csv')

# %%
training = training.dropna()

# %%
training['Image'] = training['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))

# %%
X = np.asarray([training['Image']], dtype=np.uint8).reshape(training.shape[0],96,96,1)

# %%
y = training.drop(['Image'], axis=1)

# %%
y_ndarray = y.to_numpy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_ndarray, test_size=0.3, random_state=42)

# %%
model = Sequential()

# %%
def add_model(model, filters, maxpooling, *inputshape):   
    if inputshape:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False, input_shape=(96,96,1)))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
    else:
      if maxpooling:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())
        model.add(MaxPool2D(pool_size=(2, 2)))
      else:
        model.add(Convolution2D(filters, (5,5), padding='same', use_bias=False))
        model.add(LeakyReLU(alpha = 0.1))
        model.add(BatchNormalization())

# %%
add_model(model, 32, False, True)

# %%
add_model(model, 32, True)
add_model(model, 64, False)
add_model(model, 64, True)
add_model(model, 128, False)
add_model(model, 128, True)
add_model(model, 256, False)
add_model(model, 256, True)
add_model(model, 512, False)
add_model(model, 512, True)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))

# %%
model.compile(optimizer='Adam', loss='mse', metrics=['mae', 'acc'])

# %%
from keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath = 'layer10_epoc100_kernel5p5_drop0p1.hdf5', monitor='val_mae', verbose=1, save_best_only=False)

# %%
history = model.fit(X_train, y_train, epochs=100, validation_split=0.02, callbacks=[checkpointer])
# Out:
# Train on 1468 samples, validate on 30 samples
# Epoch 1/100
# 1468/1468 [==============================] - 628s 428ms/step - loss: 209.9967 - mae: 9.0436 - acc: 0.3924 - val_loss: 2145631.0000 - val_mae: 1264.2333 - val_acc: 0.2000
#
# Epoch 00001: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 2/100
# 1468/1468 [==============================] - 452s 308ms/step - loss: 34.7538 - mae: 4.6041 - acc: 0.4707 - val_loss: 5520.4160 - val_mae: 57.9527 - val_acc: 0.2333
#
# Epoch 00002: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 3/100
# 1468/1468 [==============================] - 391s 266ms/step - loss: 27.2524 - mae: 4.0963 - acc: 0.5068 - val_loss: 302.6995 - val_mae: 13.5397 - val_acc: 0.7667
#
# Epoch 00003: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 4/100
# 1468/1468 [==============================] - 411s 280ms/step - loss: 24.2443 - mae: 3.8413 - acc: 0.5320 - val_loss: 71.4164 - val_mae: 7.2185 - val_acc: 0.7333
#
# Epoch 00004: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 5/100
# 1468/1468 [==============================] - 405s 276ms/step - loss: 22.4334 - mae: 3.6956 - acc: 0.5593 - val_loss: 26.0874 - val_mae: 4.1635 - val_acc: 0.7667
#
# Epoch 00005: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 6/100
# 1468/1468 [==============================] - 401s 273ms/step - loss: 20.0696 - mae: 3.5040 - acc: 0.5674 - val_loss: 19.5475 - val_mae: 3.4334 - val_acc: 0.5333
#
# Epoch 00006: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 7/100
# 1468/1468 [==============================] - 428s 291ms/step - loss: 17.8210 - mae: 3.3009 - acc: 0.5865 - val_loss: 18.1093 - val_mae: 3.3710 - val_acc: 0.7667
#
# Epoch 00007: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 8/100
# 1468/1468 [==============================] - 406s 277ms/step - loss: 17.6311 - mae: 3.2704 - acc: 0.5995 - val_loss: 11.4479 - val_mae: 2.4518 - val_acc: 0.7333
#
# Epoch 00008: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 9/100
# 1468/1468 [==============================] - 408s 278ms/step - loss: 17.0195 - mae: 3.2167 - acc: 0.6144 - val_loss: 17.9019 - val_mae: 3.1747 - val_acc: 0.7667
#
# Epoch 00009: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 10/100
# 1468/1468 [==============================] - 388s 264ms/step - loss: 18.7825 - mae: 3.3606 - acc: 0.6144 - val_loss: 7.0537 - val_mae: 1.9697 - val_acc: 0.7333
#
# Epoch 00010: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 11/100
# 1468/1468 [==============================] - 394s 268ms/step - loss: 14.4799 - mae: 2.9544 - acc: 0.6008 - val_loss: 17.2058 - val_mae: 3.4119 - val_acc: 0.7000
#
# Epoch 00011: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 12/100
# 1468/1468 [==============================] - 426s 290ms/step - loss: 15.0677 - mae: 3.0199 - acc: 0.6178 - val_loss: 8.4032 - val_mae: 2.1955 - val_acc: 0.7667
#
# Epoch 00012: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 13/100
# 1468/1468 [==============================] - 434s 296ms/step - loss: 12.9592 - mae: 2.7897 - acc: 0.6437 - val_loss: 6.7541 - val_mae: 1.9703 - val_acc: 0.7667
#
# Epoch 00013: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 14/100
# 1468/1468 [==============================] - 455s 310ms/step - loss: 13.2576 - mae: 2.8151 - acc: 0.6465 - val_loss: 11.0994 - val_mae: 2.6500 - val_acc: 0.7667
#
# Epoch 00014: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 15/100
# 1468/1468 [==============================] - 401s 273ms/step - loss: 12.4616 - mae: 2.7276 - acc: 0.6424 - val_loss: 6.5144 - val_mae: 1.8656 - val_acc: 0.8000
#
# Epoch 00015: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 16/100
# 1468/1468 [==============================] - 439s 299ms/step - loss: 12.4590 - mae: 2.7504 - acc: 0.6873 - val_loss: 7.7654 - val_mae: 1.9754 - val_acc: 0.8000
#
# Epoch 00016: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 17/100
# 1468/1468 [==============================] - 410s 279ms/step - loss: 10.6528 - mae: 2.5248 - acc: 0.6580 - val_loss: 7.1645 - val_mae: 1.8618 - val_acc: 0.8000
#
# Epoch 00017: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 18/100
# 1468/1468 [==============================] - 378s 257ms/step - loss: 10.1020 - mae: 2.4595 - acc: 0.6683 - val_loss: 6.3407 - val_mae: 1.8829 - val_acc: 0.7667
#
# Epoch 00018: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 19/100
# 1468/1468 [==============================] - 426s 290ms/step - loss: 13.8798 - mae: 2.8935 - acc: 0.6540 - val_loss: 6.8451 - val_mae: 2.0190 - val_acc: 0.7667
#
# Epoch 00019: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 20/100
# 1468/1468 [==============================] - 420s 286ms/step - loss: 11.6454 - mae: 2.6428 - acc: 0.6703 - val_loss: 7.5110 - val_mae: 1.9966 - val_acc: 0.8333
#
# Epoch 00020: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 21/100
# 1468/1468 [==============================] - 407s 277ms/step - loss: 12.3771 - mae: 2.7338 - acc: 0.6798 - val_loss: 5.2320 - val_mae: 1.6598 - val_acc: 0.8333
#
# Epoch 00021: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 22/100
# 1468/1468 [==============================] - 381s 260ms/step - loss: 10.7432 - mae: 2.5409 - acc: 0.7050 - val_loss: 5.6132 - val_mae: 1.7874 - val_acc: 0.8667
#
# Epoch 00022: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 23/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 9.5758 - mae: 2.3836 - acc: 0.6846 - val_loss: 4.5751 - val_mae: 1.5929 - val_acc: 0.8000
#
# Epoch 00023: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 24/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 9.5492 - mae: 2.3852 - acc: 0.6866 - val_loss: 8.2127 - val_mae: 2.1474 - val_acc: 0.8667
#
# Epoch 00024: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 25/100
# 1468/1468 [==============================] - 440s 300ms/step - loss: 11.2837 - mae: 2.5972 - acc: 0.6785 - val_loss: 5.3074 - val_mae: 1.6662 - val_acc: 0.6667
#
# Epoch 00025: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 26/100
# 1468/1468 [==============================] - 418s 285ms/step - loss: 9.0922 - mae: 2.3332 - acc: 0.6935 - val_loss: 7.5408 - val_mae: 2.2167 - val_acc: 0.7667
#
# Epoch 00026: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 27/100
# 1468/1468 [==============================] - 467s 318ms/step - loss: 9.6478 - mae: 2.4012 - acc: 0.6887 - val_loss: 5.2409 - val_mae: 1.6006 - val_acc: 0.8000
#
# Epoch 00027: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 28/100
# 1468/1468 [==============================] - 520s 354ms/step - loss: 9.2346 - mae: 2.3470 - acc: 0.7146 - val_loss: 12.0557 - val_mae: 2.9452 - val_acc: 0.9000
#
# Epoch 00028: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 29/100
# 1468/1468 [==============================] - 508s 346ms/step - loss: 11.3019 - mae: 2.6120 - acc: 0.7125 - val_loss: 21.2613 - val_mae: 4.1798 - val_acc: 0.9000
#
# Epoch 00029: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 30/100
# 1468/1468 [==============================] - 470s 320ms/step - loss: 9.4782 - mae: 2.3774 - acc: 0.6894 - val_loss: 8.4008 - val_mae: 2.3040 - val_acc: 0.8000
#
# Epoch 00030: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 31/100
# 1468/1468 [==============================] - 426s 290ms/step - loss: 9.8841 - mae: 2.4388 - acc: 0.7037 - val_loss: 10.9998 - val_mae: 2.5841 - val_acc: 0.7667
#
# Epoch 00031: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 32/100
# 1468/1468 [==============================] - 477s 325ms/step - loss: 7.5038 - mae: 2.1142 - acc: 0.7139 - val_loss: 3.5601 - val_mae: 1.4134 - val_acc: 0.7667
#
# Epoch 00032: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 33/100
# 1468/1468 [==============================] - 418s 285ms/step - loss: 7.6120 - mae: 2.1326 - acc: 0.7309 - val_loss: 5.2967 - val_mae: 1.7946 - val_acc: 0.8333
#
# Epoch 00033: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 34/100
# 1468/1468 [==============================] - 458s 312ms/step - loss: 6.6934 - mae: 1.9923 - acc: 0.7371 - val_loss: 4.4280 - val_mae: 1.5336 - val_acc: 0.7667
# Epoch 00034: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 35/100
# 1468/1468 [==============================] - 408s 278ms/step - loss: 6.7104 - mae: 1.9921 - acc: 0.7391 - val_loss: 3.9997 - val_mae: 1.3863 - val_acc: 0.5667
#
# Epoch 00035: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 36/100
# 1468/1468 [==============================] - 455s 310ms/step - loss: 6.7024 - mae: 1.9957 - acc: 0.7214 - val_loss: 5.6249 - val_mae: 1.8303 - val_acc: 0.8333
#
# Epoch 00036: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 37/100
# 1468/1468 [==============================] - 429s 292ms/step - loss: 7.0956 - mae: 2.0547 - acc: 0.7343 - val_loss: 5.2626 - val_mae: 1.8186 - val_acc: 0.8667
#
# Epoch 00037: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 38/100
# 1468/1468 [==============================] - 420s 286ms/step - loss: 7.8295 - mae: 2.1403 - acc: 0.7446 - val_loss: 3.3261 - val_mae: 1.3107 - val_acc: 0.9333
#
# Epoch 00038: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 39/100
# 1468/1468 [==============================] - 452s 308ms/step - loss: 6.9564 - mae: 2.0360 - acc: 0.7371 - val_loss: 6.2049 - val_mae: 2.0884 - val_acc: 0.8333
#
# Epoch 00039: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 40/100
# 1468/1468 [==============================] - 466s 317ms/step - loss: 7.4921 - mae: 2.1064 - acc: 0.7493 - val_loss: 4.7393 - val_mae: 1.7724 - val_acc: 0.9333
#
# Epoch 00040: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 41/100
# 1468/1468 [==============================] - 399s 272ms/step - loss: 6.7263 - mae: 1.9937 - acc: 0.7371 - val_loss: 2.9848 - val_mae: 1.2536 - val_acc: 0.8333
#
# Epoch 00041: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 42/100
# 1468/1468 [==============================] - 396s 270ms/step - loss: 5.9382 - mae: 1.8760 - acc: 0.7391 - val_loss: 3.5956 - val_mae: 1.3484 - val_acc: 0.8667
#
# Epoch 00042: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 43/100
# 1468/1468 [==============================] - 450s 307ms/step - loss: 7.4623 - mae: 2.1120 - acc: 0.7541 - val_loss: 4.4129 - val_mae: 1.5728 - val_acc: 0.9000
#
# Epoch 00043: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 44/100
# 1468/1468 [==============================] - 459s 313ms/step - loss: 7.1732 - mae: 2.0688 - acc: 0.7405 - val_loss: 4.3450 - val_mae: 1.6006 - val_acc: 0.9000
#
# Epoch 00044: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 45/100
# 1468/1468 [==============================] - 455s 310ms/step - loss: 6.2530 - mae: 1.9162 - acc: 0.7439 - val_loss: 3.0700 - val_mae: 1.3033 - val_acc: 0.9000
#
# Epoch 00045: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 46/100
# 1468/1468 [==============================] - 471s 321ms/step - loss: 6.4989 - mae: 1.9504 - acc: 0.7582 - val_loss: 7.0593 - val_mae: 2.1835 - val_acc: 0.7333
#
# Epoch 00046: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 47/100
# 1468/1468 [==============================] - 457s 311ms/step - loss: 6.8084 - mae: 2.0090 - acc: 0.7602 - val_loss: 5.2361 - val_mae: 1.8904 - val_acc: 0.8667
#
# Epoch 00047: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 48/100
# 1468/1468 [==============================] - 452s 308ms/step - loss: 5.7892 - mae: 1.8510 - acc: 0.7418 - val_loss: 6.7037 - val_mae: 2.1449 - val_acc: 0.9333
#
# Epoch 00048: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 49/100
# 1468/1468 [==============================] - 444s 302ms/step - loss: 6.8318 - mae: 1.9972 - acc: 0.7609 - val_loss: 3.1728 - val_mae: 1.2528 - val_acc: 0.7000
#
# Epoch 00049: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 50/100
# 1468/1468 [==============================] - 429s 292ms/step - loss: 6.7812 - mae: 2.0019 - acc: 0.7473 - val_loss: 3.4755 - val_mae: 1.4504 - val_acc: 0.8667
#
# Epoch 00050: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 51/100
# 1468/1468 [==============================] - 451s 307ms/step - loss: 6.2296 - mae: 1.9123 - acc: 0.7704 - val_loss: 3.2311 - val_mae: 1.3229 - val_acc: 0.8667
#
# Epoch 00051: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 52/100
# 1468/1468 [==============================] - 438s 298ms/step - loss: 8.6383 - mae: 2.2572 - acc: 0.7663 - val_loss: 5.9541 - val_mae: 1.9555 - val_acc: 0.8667
#
# Epoch 00052: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 53/100
# 1468/1468 [==============================] - 432s 294ms/step - loss: 6.3365 - mae: 1.9311 - acc: 0.7841 - val_loss: 4.8318 - val_mae: 1.6945 - val_acc: 0.8333
#
# Epoch 00053: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 54/100
# 1468/1468 [==============================] - 406s 277ms/step - loss: 5.9551 - mae: 1.8683 - acc: 0.7657 - val_loss: 9.7049 - val_mae: 2.6581 - val_acc: 0.9333
#
# Epoch 00054: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 55/100
# 1468/1468 [==============================] - 408s 278ms/step - loss: 5.2637 - mae: 1.7615 - acc: 0.7793 - val_loss: 2.5952 - val_mae: 1.1631 - val_acc: 0.9333
#
# Epoch 00055: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 56/100
# 1468/1468 [==============================] - 488s 333ms/step - loss: 5.4887 - mae: 1.7938 - acc: 0.7534 - val_loss: 2.4937 - val_mae: 1.1547 - val_acc: 0.9000
#
# Epoch 00056: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 57/100
# 1468/1468 [==============================] - 513s 350ms/step - loss: 5.5780 - mae: 1.8188 - acc: 0.7820 - val_loss: 2.8960 - val_mae: 1.1580 - val_acc: 0.9000
#
# Epoch 00057: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 58/100
# 1468/1468 [==============================] - 454s 309ms/step - loss: 5.5070 - mae: 1.8037 - acc: 0.7868 - val_loss: 3.2762 - val_mae: 1.3399 - val_acc: 0.8333
#
# Epoch 00058: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 59/100
# 1468/1468 [==============================] - 399s 272ms/step - loss: 6.1792 - mae: 1.9081 - acc: 0.7868 - val_loss: 4.5143 - val_mae: 1.7109 - val_acc: 0.9333
#
# Epoch 00059: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 60/100
# 1468/1468 [==============================] - 407s 277ms/step - loss: 5.9636 - mae: 1.8674 - acc: 0.7827 - val_loss: 2.9970 - val_mae: 1.2361 - val_acc: 0.8667
#
# Epoch 00060: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 61/100
# 1468/1468 [==============================] - 418s 285ms/step - loss: 4.7921 - mae: 1.6844 - acc: 0.7766 - val_loss: 3.5782 - val_mae: 1.4444 - val_acc: 0.9333
#
# Epoch 00061: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 62/100
# 1468/1468 [==============================] - 440s 300ms/step - loss: 5.0711 - mae: 1.7194 - acc: 0.7759 - val_loss: 2.7272 - val_mae: 1.1700 - val_acc: 0.8333
#
# Epoch 00062: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 63/100
# 1468/1468 [==============================] - 411s 280ms/step - loss: 4.7102 - mae: 1.6681 - acc: 0.7963 - val_loss: 8.7567 - val_mae: 2.4595 - val_acc: 0.6667
#
# Epoch 00063: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 64/100
# 1468/1468 [==============================] - 410s 279ms/step - loss: 6.1267 - mae: 1.9074 - acc: 0.7909 - val_loss: 3.8580 - val_mae: 1.5411 - val_acc: 0.8667
#
# Epoch 00064: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 65/100
# 1468/1468 [==============================] - 439s 299ms/step - loss: 4.8454 - mae: 1.6851 - acc: 0.7936 - val_loss: 2.9640 - val_mae: 1.2757 - val_acc: 0.8000
#
# Epoch 00065: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 66/100
# 1468/1468 [==============================] - 473s 322ms/step - loss: 5.4958 - mae: 1.8040 - acc: 0.8018 - val_loss: 6.5481 - val_mae: 2.0329 - val_acc: 0.8000
#
# Epoch 00066: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 67/100
# 1468/1468 [==============================] - 445s 303ms/step - loss: 5.4911 - mae: 1.7926 - acc: 0.7738 - val_loss: 5.8701 - val_mae: 1.9913 - val_acc: 0.8667
#
# Epoch 00067: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 68/100
# 1468/1468 [==============================] - 434s 296ms/step - loss: 4.8322 - mae: 1.6780 - acc: 0.7909 - val_loss: 4.2482 - val_mae: 1.6401 - val_acc: 0.9333
# Epoch 00068: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 69/100
# 1468/1468 [==============================] - 443s 302ms/step - loss: 4.7900 - mae: 1.6716 - acc: 0.7922 - val_loss: 2.7931 - val_mae: 1.2788 - val_acc: 0.9000
#
# Epoch 00069: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 70/100
# 1468/1468 [==============================] - 435s 297ms/step - loss: 4.7268 - mae: 1.6637 - acc: 0.7888 - val_loss: 5.8002 - val_mae: 2.0452 - val_acc: 0.8667
#
# Epoch 00070: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 71/100
# 1468/1468 [==============================] - 444s 302ms/step - loss: 5.0245 - mae: 1.7259 - acc: 0.8093 - val_loss: 3.0334 - val_mae: 1.3129 - val_acc: 0.9333
#
# Epoch 00071: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 72/100
# 1468/1468 [==============================] - 444s 303ms/step - loss: 4.2574 - mae: 1.5797 - acc: 0.8093 - val_loss: 3.5986 - val_mae: 1.4325 - val_acc: 0.8333
#
# Epoch 00072: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 73/100
# 1468/1468 [==============================] - 419s 286ms/step - loss: 4.7240 - mae: 1.6639 - acc: 0.8045 - val_loss: 2.4643 - val_mae: 1.1588 - val_acc: 0.9333
#
# Epoch 00073: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 74/100
# 1468/1468 [==============================] - 437s 298ms/step - loss: 4.6257 - mae: 1.6530 - acc: 0.8025 - val_loss: 3.9598 - val_mae: 1.5398 - val_acc: 0.8667
#
# Epoch 00074: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 75/100
# 1468/1468 [==============================] - 431s 293ms/step - loss: 4.1137 - mae: 1.5484 - acc: 0.8168 - val_loss: 3.2055 - val_mae: 1.3381 - val_acc: 0.9000
#
# Epoch 00075: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 76/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 4.5676 - mae: 1.6278 - acc: 0.8093 - val_loss: 2.4447 - val_mae: 1.1166 - val_acc: 0.9000
#
# Epoch 00076: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 77/100
# 1468/1468 [==============================] - 388s 264ms/step - loss: 4.5204 - mae: 1.6370 - acc: 0.8086 - val_loss: 2.4142 - val_mae: 1.1066 - val_acc: 0.8667
#
# Epoch 00077: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 78/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 4.6902 - mae: 1.6705 - acc: 0.7997 - val_loss: 6.2607 - val_mae: 2.1316 - val_acc: 0.9000
#
# Epoch 00078: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 79/100
# 1468/1468 [==============================] - 422s 288ms/step - loss: 5.1329 - mae: 1.7472 - acc: 0.8025 - val_loss: 2.9799 - val_mae: 1.3005 - val_acc: 0.8667
#
# Epoch 00079: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 80/100
# 1468/1468 [==============================] - 398s 271ms/step - loss: 5.3644 - mae: 1.7795 - acc: 0.8079 - val_loss: 2.6710 - val_mae: 1.1648 - val_acc: 0.8667
#
# Epoch 00080: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 81/100
# 1468/1468 [==============================] - 453s 308ms/step - loss: 4.4817 - mae: 1.6053 - acc: 0.8072 - val_loss: 2.4310 - val_mae: 1.1430 - val_acc: 0.8333
#
# Epoch 00081: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 82/100
# 1468/1468 [==============================] - 453s 308ms/step - loss: 4.7233 - mae: 1.6748 - acc: 0.8222 - val_loss: 2.1358 - val_mae: 1.0130 - val_acc: 0.8667
#
# Epoch 00082: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 83/100
# 1468/1468 [==============================] - 453s 309ms/step - loss: 4.6534 - mae: 1.6495 - acc: 0.8127 - val_loss: 2.0667 - val_mae: 1.0178 - val_acc: 0.8667
#
# Epoch 00083: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 84/100
# 1468/1468 [==============================] - 463s 315ms/step - loss: 4.1984 - mae: 1.5707 - acc: 0.8134 - val_loss: 2.7182 - val_mae: 1.2424 - val_acc: 0.9000
#
# Epoch 00084: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 85/100
# 1468/1468 [==============================] - 431s 293ms/step - loss: 4.0469 - mae: 1.5399 - acc: 0.8079 - val_loss: 2.3405 - val_mae: 1.1217 - val_acc: 0.9000
#
# Epoch 00085: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 86/100
# 1468/1468 [==============================] - 472s 322ms/step - loss: 4.6627 - mae: 1.6551 - acc: 0.8011 - val_loss: 3.4789 - val_mae: 1.4121 - val_acc: 0.8000
#
# Epoch 00086: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 87/100
# 1468/1468 [==============================] - 463s 316ms/step - loss: 4.3130 - mae: 1.5935 - acc: 0.8045 - val_loss: 5.7129 - val_mae: 2.0027 - val_acc: 0.9000
#
# Epoch 00087: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 88/100
# 1468/1468 [==============================] - 443s 302ms/step - loss: 4.6061 - mae: 1.6495 - acc: 0.8147 - val_loss: 2.7319 - val_mae: 1.1927 - val_acc: 0.9333
#
# Epoch 00088: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 89/100
# 1468/1468 [==============================] - 405s 276ms/step - loss: 5.6726 - mae: 1.8320 - acc: 0.8202 - val_loss: 7.6376 - val_mae: 2.3023 - val_acc: 0.9000
#
# Epoch 00089: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 90/100
# 1468/1468 [==============================] - 435s 296ms/step - loss: 4.0487 - mae: 1.5404 - acc: 0.8256 - val_loss: 8.0108 - val_mae: 2.3792 - val_acc: 0.8333
#
# Epoch 00090: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 91/100
# 1468/1468 [==============================] - 428s 292ms/step - loss: 4.9087 - mae: 1.7019 - acc: 0.8208 - val_loss: 2.2593 - val_mae: 1.1009 - val_acc: 0.9000
#
# Epoch 00091: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 92/100
# 1468/1468 [==============================] - 435s 296ms/step - loss: 5.7222 - mae: 1.8500 - acc: 0.8045 - val_loss: 4.2815 - val_mae: 1.4842 - val_acc: 0.8333
#
# Epoch 00092: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 93/100
# 1468/1468 [==============================] - 447s 305ms/step - loss: 4.8900 - mae: 1.6946 - acc: 0.8140 - val_loss: 10.8080 - val_mae: 2.8325 - val_acc: 0.8667
#
# Epoch 00093: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 94/100
# 1468/1468 [==============================] - 411s 280ms/step - loss: 4.0497 - mae: 1.5431 - acc: 0.8113 - val_loss: 5.0989 - val_mae: 1.8242 - val_acc: 0.8333
#
# Epoch 00094: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 95/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 4.0170 - mae: 1.5358 - acc: 0.8120 - val_loss: 2.6062 - val_mae: 1.1143 - val_acc: 0.9333
#
# Epoch 00095: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 96/100
# 1468/1468 [==============================] - 390s 265ms/step - loss: 4.4347 - mae: 1.6212 - acc: 0.8093 - val_loss: 5.1293 - val_mae: 1.9138 - val_acc: 0.8000
#
# Epoch 00096: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 97/100
# 1468/1468 [==============================] - 386s 263ms/step - loss: 4.3835 - mae: 1.6120 - acc: 0.8283 - val_loss: 3.0469 - val_mae: 1.3455 - val_acc: 0.8333
#
# Epoch 00097: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 98/100
# 1468/1468 [==============================] - 385s 262ms/step - loss: 3.7076 - mae: 1.4768 - acc: 0.8297 - val_loss: 3.2800 - val_mae: 1.3958 - val_acc: 0.8667
#
# Epoch 00098: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 99/100
# 1468/1468 [==============================] - 421s 287ms/step - loss: 4.0063 - mae: 1.5307 - acc: 0.8345 - val_loss: 3.0247 - val_mae: 1.3652 - val_acc: 0.8333
#
# Epoch 00099: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5
# Epoch 100/100
# 1468/1468 [==============================] - 476s 324ms/step - loss: 5.0292 - mae: 1.7407 - acc: 0.8283 - val_loss: 2.0967 - val_mae: 1.0457 - val_acc: 0.8000
#
# Epoch 00100: saving model to layer10_epoc100_kernel5p5_drop0p1.hdf5

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.465646870782442
# Test accuracy: 1.115580677986145

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 2.2858125175642448
# Test accuracy: 1.0961841344833374

# %%
test['Image'] = test['Image'].apply(lambda x: np.fromstring(x, dtype=int, sep=' ').reshape((96,96)))
test_X = np.asarray([test['Image']], dtype=np.uint8).reshape(test.shape[0],96,96,1)
train_predicts = model.predict(X_train)

# %%
plt.imshow(X_train[0].reshape((96,96)), cmap='gray')

for i in range(1,31,2):
    plt.plot(train_predicts[0][i-1], train_predicts[0][i], 'ro')
    plt.plot(y_train[0][i-1], y_train[0][i], 'x', color='green')

plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['loss'], linewidth=2, label="train")
plt.plot(history.history['val_loss'], linewidth=2, label="val ")
plt.legend()
plt.title('Loss vs Epoch')
plt.grid()
plt.yscale('log')
plt.xlabel("Epoch")
plt.ylabel("Log Loss")
fig= plt.figure(figsize=(20,15))
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['mae'], linewidth=2)
plt.plot(history.history['val_mae'], linewidth=2)
plt.title('Mean Absolute Error vs Epoch')
plt.ylabel('Mean Absolute Error')
plt.xlabel('Epochs')
plt.yscale('log')
plt.grid()
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(13,6))
plt.plot(history.history['acc'], linewidth=2)
plt.plot(history.history['val_acc'], linewidth=2)
plt.title('Accuracy vs Epoch')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
predict = model.predict(test_X)

# %%
header = list(y.columns)

# %%
df_predict = pd.DataFrame(predict, columns = header)

# %%
for i in range(IdLookupTable.shape[0]):
    IdLookupTable.Location[i] = df_predict.loc[IdLookupTable.ImageId[i]-1][IdLookupTable.FeatureName[i]]

# %%
SampleSubmission.Location = IdLookupTable.Location

# %%
SampleSubmission.to_csv('submission_100_epochs_kernel5x5_2.csv', index=False)

# %%
pd.DataFrame(history.history.items()).to_csv('history_submission_100_epochs_kernel5x5.csv', index=False)
